# %%
import os
import tensorflow as tf
import models.unet as unet
from model_util import ImgTester, model_path
from model_util import Saver
from model_util import load_all_imgs

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available", len(physical_devices))
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Num GPUs Available 1

# %%
kernel_size=(3, 3)
padding="same"
strides=1
image_size = (256,256)
epochs = 30
batch_size= 8
validation_split= 0.2
f = [16, 32, 64, 128, 256]
threshold = 0.5
metric_name = "mean_iou_threshold"
metric = tf.keras.metrics.MeanIoU(num_classes=2, name=metric_name)
base_output_path = '..\\imagens_cra\\result\\unet_mean_iou_threshold_epoch_'+str(epochs)+'_size_'+str(image_size)
x_dir = "../imagens_cra/train/cra"
y_dir = "../imagens_cra/validation/cra"

# %%
# Load images
trainImgs = load_all_imgs(x_dir,image_size, 1)
validImgs = load_all_imgs(y_dir,image_size, 0)
# Out:
# ../imagens_cra/train/cra found 659 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ../imagens_cra/validation/cra found 659 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||

# %%
import matplotlib.pyplot as plt
plt.imshow(trainImgs[0])

# %%
plt.imshow(validImgs[0], cmap=plt.cm.binary)

# %%
def mean_iou_threshold(y_true, y_pred):
    y_pred = y_pred.numpy()
    y_pred[y_pred > threshold]= 1
    y_pred[y_pred <= threshold] = 0
    metric.reset_states()
    metric.update_state(y_true, y_pred)
    return metric.result().numpy()

model = unet.build(image_size, f)
model.compile(run_eagerly=True, optimizer="adam", loss="binary_crossentropy", metrics=[mean_iou_threshold])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 16) 2320        conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 16) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 32) 4640        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 32) 9248        conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 64)   36928       conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 128)  147584      conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 256)  590080      conv2d_8[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 256)  0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 384)  0           up_sampling2d[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 256)  884992      concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 256)  590080      conv2d_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 256)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 320)  0           up_sampling2d_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 128)  368768      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 128)  147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 128 0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 160 0           up_sampling2d_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 64) 92224       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 64) 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 80) 0           up_sampling2d_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 32) 23072       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 32) 9248        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 1)  33          conv2d_17[0][0]
# ==================================================================================================
# Total params: 3,331,697
# Trainable params: 3,331,697
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
try:
    os.mkdir(base_output_path)
except OSError as error:
  pass

callbacks = tf.keras.callbacks.ModelCheckpoint(
    model_path(base_output_path),
    monitor=metric_name, verbose=0,
    save_best_only=True,
    mode='auto',
    save_freq='epoch',
)
history = model.fit(
    trainImgs, validImgs,
    epochs=epochs,  batch_size=batch_size, callbacks=callbacks,
    validation_split=validation_split,
)
# Out:
# Epoch 1/30
# 66/66 [==============================] - 31s 367ms/step - loss: 0.5337 - mean_iou_threshold: 0.4019 - val_loss: 0.3522 - val_mean_iou_threshold: 0.4020
# Epoch 2/30
# 66/66 [==============================] - 19s 284ms/step - loss: 0.3572 - mean_iou_threshold: 0.4805 - val_loss: 0.2243 - val_mean_iou_threshold: 0.7510
# Epoch 3/30
# 66/66 [==============================] - 19s 284ms/step - loss: 0.2229 - mean_iou_threshold: 0.7457 - val_loss: 0.1637 - val_mean_iou_threshold: 0.8223
# Epoch 4/30
# 66/66 [==============================] - 19s 285ms/step - loss: 0.1343 - mean_iou_threshold: 0.8478 - val_loss: 0.0755 - val_mean_iou_threshold: 0.9097
# Epoch 5/30
# 66/66 [==============================] - 19s 284ms/step - loss: 0.0699 - mean_iou_threshold: 0.9141 - val_loss: 0.0671 - val_mean_iou_threshold: 0.9220
# Epoch 6/30
# 66/66 [==============================] - 19s 285ms/step - loss: 0.0585 - mean_iou_threshold: 0.9344 - val_loss: 0.0978 - val_mean_iou_threshold: 0.8954
# Epoch 7/30
# 66/66 [==============================] - 19s 285ms/step - loss: 0.0654 - mean_iou_threshold: 0.9263 - val_loss: 0.0648 - val_mean_iou_threshold: 0.9256
# Epoch 8/30
# 66/66 [==============================] - 19s 286ms/step - loss: 0.0551 - mean_iou_threshold: 0.9358 - val_loss: 0.0489 - val_mean_iou_threshold: 0.9425
# Epoch 9/30
# 66/66 [==============================] - 19s 287ms/step - loss: 0.0377 - mean_iou_threshold: 0.9545 - val_loss: 0.0382 - val_mean_iou_threshold: 0.9532
# Epoch 10/30
# 66/66 [==============================] - 19s 287ms/step - loss: 0.0286 - mean_iou_threshold: 0.9643 - val_loss: 0.0301 - val_mean_iou_threshold: 0.9632
# Epoch 11/30
# 66/66 [==============================] - 19s 288ms/step - loss: 0.0236 - mean_iou_threshold: 0.9689 - val_loss: 0.0274 - val_mean_iou_threshold: 0.9661
# Epoch 12/30
# 66/66 [==============================] - 19s 288ms/step - loss: 0.0221 - mean_iou_threshold: 0.9714 - val_loss: 0.0277 - val_mean_iou_threshold: 0.9667
# Epoch 13/30
# 66/66 [==============================] - 19s 288ms/step - loss: 0.0207 - mean_iou_threshold: 0.9729 - val_loss: 0.0265 - val_mean_iou_threshold: 0.9680
# Epoch 14/30
# 66/66 [==============================] - 19s 287ms/step - loss: 0.0196 - mean_iou_threshold: 0.9747 - val_loss: 0.0285 - val_mean_iou_threshold: 0.9673
# Epoch 15/30
# 66/66 [==============================] - 19s 286ms/step - loss: 0.0187 - mean_iou_threshold: 0.9756 - val_loss: 0.0261 - val_mean_iou_threshold: 0.9694
# Epoch 16/30
# 66/66 [==============================] - 19s 286ms/step - loss: 0.0187 - mean_iou_threshold: 0.9759 - val_loss: 0.0261 - val_mean_iou_threshold: 0.9697
# Epoch 17/30
# 66/66 [==============================] - 19s 286ms/step - loss: 0.0176 - mean_iou_threshold: 0.9767 - val_loss: 0.0252 - val_mean_iou_threshold: 0.9695
# Epoch 18/30
# 66/66 [==============================] - 19s 286ms/step - loss: 0.0206 - mean_iou_threshold: 0.9739 - val_loss: 0.0466 - val_mean_iou_threshold: 0.9436
# Epoch 19/30
# 66/66 [==============================] - 19s 287ms/step - loss: 0.0294 - mean_iou_threshold: 0.9647 - val_loss: 0.0290 - val_mean_iou_threshold: 0.9661
# Epoch 20/30
# 66/66 [==============================] - 19s 287ms/step - loss: 0.0230 - mean_iou_threshold: 0.9716 - val_loss: 0.0346 - val_mean_iou_threshold: 0.9602
# Epoch 21/30
# 66/66 [==============================] - 19s 287ms/step - loss: 0.0255 - mean_iou_threshold: 0.9690 - val_loss: 0.0247 - val_mean_iou_threshold: 0.9687
# Epoch 22/30
# 66/66 [==============================] - 19s 287ms/step - loss: 0.0189 - mean_iou_threshold: 0.9757 - val_loss: 0.0233 - val_mean_iou_threshold: 0.9703
# Epoch 23/30
# 66/66 [==============================] - 19s 287ms/step - loss: 0.0181 - mean_iou_threshold: 0.9765 - val_loss: 0.0237 - val_mean_iou_threshold: 0.9715
# Epoch 24/30
# 66/66 [==============================] - 19s 287ms/step - loss: 0.0167 - mean_iou_threshold: 0.9785 - val_loss: 0.0222 - val_mean_iou_threshold: 0.9730
# Epoch 25/30
# 66/66 [==============================] - 19s 287ms/step - loss: 0.0171 - mean_iou_threshold: 0.9779 - val_loss: 0.0227 - val_mean_iou_threshold: 0.9728
# Epoch 26/30
# 66/66 [==============================] - 19s 287ms/step - loss: 0.0166 - mean_iou_threshold: 0.9781 - val_loss: 0.0246 - val_mean_iou_threshold: 0.9719
# Epoch 27/30
# 66/66 [==============================] - 19s 288ms/step - loss: 0.0161 - mean_iou_threshold: 0.9790 - val_loss: 0.0245 - val_mean_iou_threshold: 0.9726
# Epoch 28/30
# 66/66 [==============================] - 19s 288ms/step - loss: 0.0156 - mean_iou_threshold: 0.9798 - val_loss: 0.0248 - val_mean_iou_threshold: 0.9724
# Epoch 29/30
# 66/66 [==============================] - 19s 287ms/step - loss: 0.0148 - mean_iou_threshold: 0.9804 - val_loss: 0.0241 - val_mean_iou_threshold: 0.9725
# Epoch 30/30
# 66/66 [==============================] - 19s 288ms/step - loss: 0.0147 - mean_iou_threshold: 0.9807 - val_loss: 0.0239 - val_mean_iou_threshold: 0.9735

# %%
internal_saver = Saver(model, history, base_output_path)
internal_saver.save_metrics(metric_name)
# Out:
# saved to: ..\imagens_cra\result\unet_mean_iou_threshold_epoch_30_size_(256, 256)\acc_por_epocas

# %%
internal_saver.save_loss()
# Out:
# saved to: ..\imagens_cra\result\unet_mean_iou_threshold_epoch_30_size_(256, 256)\loss_por_epocas

# %%
imgTester = ImgTester(base_output_path, x_dir, y_dir, image_size)
imgTester_metrics = [
    metric,
    tf.keras.metrics.MeanIoU(num_classes=2),
    tf.keras.metrics.BinaryAccuracy(name="binary_accuracy", dtype=None, threshold=threshold),
]
dependencies = {
    metric_name: mean_iou_threshold,
}
imgTester.test(-1, 5, imgTester_metrics, threshold, dependencies)
# Out:
# found 659 img to test
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Write metrics to: ..\imagens_cra\result\unet_mean_iou_threshold_epoch_30_size_(256, 256)\metrics.csv

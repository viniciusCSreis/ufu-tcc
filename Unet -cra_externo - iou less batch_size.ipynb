# %%
import os
import tensorflow as tf
import models.unet as unet
from model_util import ImgTester, model_path
from model_util import Saver
from model_util import load_all_imgs

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available", len(physical_devices))
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Num GPUs Available 1

# %%
kernel_size=(3, 3)
padding="same"
strides=1
image_size = (256,256)
epochs = 30
batch_size= 1
validation_split= 0.2
f = [16, 32, 64, 128, 256]
threshold = 0.5
metric_name = "mean_iou_threshold"
metric = tf.keras.metrics.MeanIoU(num_classes=2, name=metric_name)
base_output_path = '..\\imagens_cra\\result\\unet_mean_iou_less_batchsize_'+str(epochs)+'_size_'+str(image_size)
x_dir = "../imagens_cra/train/cra"
y_dir = "../imagens_cra/validation/cra"

# %%
# Load images
trainImgs = load_all_imgs(x_dir,image_size, 1)
validImgs = load_all_imgs(y_dir,image_size, 0)
# Out:
# ../imagens_cra/train/cra found 659 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ../imagens_cra/validation/cra found 659 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||

# %%
import matplotlib.pyplot as plt
plt.imshow(trainImgs[0])

# %%
plt.imshow(validImgs[0], cmap=plt.cm.binary)

# %%
def mean_iou_threshold(y_true, y_pred):
    y_pred = y_pred.numpy()
    y_pred[y_pred > threshold]= 1
    y_pred[y_pred <= threshold] = 0
    metric.reset_states()
    metric.update_state(y_true, y_pred)
    return metric.result().numpy()

model = unet.build(image_size, f)
model.compile(run_eagerly=True, optimizer="adam", loss="binary_crossentropy", metrics=[mean_iou_threshold])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 16) 448         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 16) 2320        conv2d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 16) 0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 32) 4640        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 128, 128, 32) 9248        conv2d_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 32)   0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 64, 64)   18496       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, 64, 64)   36928       conv2d_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 64)   0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 128)  73856       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 32, 128)  147584      conv2d_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 128)  0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 256)  295168      max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 16, 16, 256)  590080      conv2d_27[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 32, 32, 256)  0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 384)  0           up_sampling2d_4[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 32, 32, 256)  884992      concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 32, 256)  590080      conv2d_29[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 64, 64, 256)  0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 320)  0           up_sampling2d_5[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 64, 64, 128)  368768      concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 64, 128)  147584      conv2d_31[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 128, 128, 128 0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 160 0           up_sampling2d_6[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 128, 128, 64) 92224       concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_33[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 256, 256, 64) 0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 80) 0           up_sampling2d_7[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 256, 256, 32) 23072       concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 256, 256, 32) 9248        conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 256, 256, 1)  289         conv2d_36[0][0]
# ==================================================================================================
# Total params: 3,331,953
# Trainable params: 3,331,953
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
try:
    os.mkdir(base_output_path)
except OSError as error:
  pass

callbacks = tf.keras.callbacks.ModelCheckpoint(
    model_path(base_output_path),
    monitor=metric_name, verbose=0,
    save_best_only=True,
    mode='auto',
    save_freq='epoch',
)
history = model.fit(
    trainImgs, validImgs,
    epochs=epochs,  batch_size=batch_size, callbacks=callbacks,
    validation_split=validation_split,
)
# Out:
# Epoch 1/30
# 527/527 [==============================] - 40s 72ms/step - loss: 0.5210 - mean_iou_threshold: 0.3972 - val_loss: 0.4838 - val_mean_iou_threshold: 0.4020
# Epoch 2/30
# 527/527 [==============================] - 42s 81ms/step - loss: 0.4448 - mean_iou_threshold: 0.4059 - val_loss: 0.3956 - val_mean_iou_threshold: 0.4022
# Epoch 3/30
#  - ETA: 25s - loss: 0.4304 - mean_iou_threshold: 0.4010
# Epoch 4/30
# 527/527 [==============================] - 39s 73ms/step - loss: 0.3448 - mean_iou_threshold: 0.5919 - val_loss: 0.2883 - val_mean_iou_threshold: 0.7382
# Epoch 5/30
# 527/527 [==============================] - 40s 75ms/step - loss: 0.2500 - mean_iou_threshold: 0.7015 - val_loss: 0.1642 - val_mean_iou_threshold: 0.8139
# Epoch 6/30
# 527/527 [==============================] - 40s 76ms/step - loss: 0.1999 - mean_iou_threshold: 0.7674 - val_loss: 0.1467 - val_mean_iou_threshold: 0.8304
# Epoch 7/30
# 527/527 [==============================] - 41s 77ms/step - loss: 0.1507 - mean_iou_threshold: 0.8214 - val_loss: 0.1323 - val_mean_iou_threshold: 0.8575
# Epoch 8/30
# 527/527 [==============================] - 40s 76ms/step - loss: 0.1091 - mean_iou_threshold: 0.8747 - val_loss: 0.1113 - val_mean_iou_threshold: 0.8785
# Epoch 9/30
# 527/527 [==============================] - 40s 77ms/step - loss: 0.0781 - mean_iou_threshold: 0.9124 - val_loss: 0.0730 - val_mean_iou_threshold: 0.9199
# Epoch 10/30
# 527/527 [==============================] - 40s 76ms/step - loss: 0.0614 - mean_iou_threshold: 0.9303 - val_loss: 0.0494 - val_mean_iou_threshold: 0.9465
# Epoch 11/30
# 527/527 [==============================] - 40s 76ms/step - loss: 0.0399 - mean_iou_threshold: 0.9522 - val_loss: 0.0423 - val_mean_iou_threshold: 0.9528
# Epoch 12/30
# 527/527 [==============================] - 41s 78ms/step - loss: 0.0301 - mean_iou_threshold: 0.9614 - val_loss: 0.0359 - val_mean_iou_threshold: 0.9560
# Epoch 13/30
# 527/527 [==============================] - 42s 79ms/step - loss: 0.0388 - mean_iou_threshold: 0.9521 - val_loss: 0.0667 - val_mean_iou_threshold: 0.9278
# Epoch 14/30
# 527/527 [==============================] - 52s 98ms/step - loss: 0.0586 - mean_iou_threshold: 0.9349 - val_loss: 0.0362 - val_mean_iou_threshold: 0.9545
# Epoch 15/30
# 527/527 [==============================] - 52s 98ms/step - loss: 0.0270 - mean_iou_threshold: 0.9630 - val_loss: 0.0452 - val_mean_iou_threshold: 0.9496
# Epoch 16/30
# 527/527 [==============================] - 43s 82ms/step - loss: 0.0331 - mean_iou_threshold: 0.9595 - val_loss: 0.0505 - val_mean_iou_threshold: 0.9357
# Epoch 17/30
# 527/527 [==============================] - 42s 79ms/step - loss: 0.0360 - mean_iou_threshold: 0.9584 - val_loss: 0.0396 - val_mean_iou_threshold: 0.9521
# Epoch 18/30
#  - ETA: 4s - loss: 0.0329 - mean_iou_threshold: 0.9619
# Epoch 19/30
#  - ETA: 41s - loss: 0.0274 - mean_iou_threshold: 0.9616
# Epoch 20/30
# 527/527 [==============================] - 51s 97ms/step - loss: 0.0263 - mean_iou_threshold: 0.9668 - val_loss: 0.0443 - val_mean_iou_threshold: 0.9506
# Epoch 21/30
# 527/527 [==============================] - 55s 104ms/step - loss: 0.0253 - mean_iou_threshold: 0.9687 - val_loss: 0.0324 - val_mean_iou_threshold: 0.9623
# Epoch 22/30
# 527/527 [==============================] - 42s 80ms/step - loss: 0.0221 - mean_iou_threshold: 0.9713 - val_loss: 0.0336 - val_mean_iou_threshold: 0.9597
# Epoch 23/30
# 527/527 [==============================] - 45s 85ms/step - loss: 0.0272 - mean_iou_threshold: 0.9683 - val_loss: 0.0297 - val_mean_iou_threshold: 0.9636
# Epoch 24/30
# 527/527 [==============================] - 47s 89ms/step - loss: 0.0208 - mean_iou_threshold: 0.9717 - val_loss: 0.0437 - val_mean_iou_threshold: 0.9527
# Epoch 25/30
#  - ETA: 33s - loss: 0.0213 - mean_iou_threshold: 0.9701
# Epoch 26/30
# 527/527 [==============================] - 60s 114ms/step - loss: 0.0333 - mean_iou_threshold: 0.9630 - val_loss: 0.0302 - val_mean_iou_threshold: 0.9613
# Epoch 27/30
#  - ETA: 4s - loss: 0.0188 - mean_iou_threshold: 0.9738
# Epoch 28/30
#  - ETA: 41s - loss: 0.0374 - mean_iou_threshold: 0.9652
# Epoch 29/30
# 260/527 [=============>................] - ETA: 25s - loss: 0.0184 - mean_iou_threshold: 0.9749

# %%
internal_saver = Saver(model, history, base_output_path)
internal_saver.save_metrics(metric_name)

# %%
internal_saver.save_loss()

# %%
imgTester = ImgTester(base_output_path, x_dir, y_dir, image_size)
imgTester_metrics = [
    metric,
    tf.keras.metrics.MeanIoU(num_classes=2),
    tf.keras.metrics.BinaryAccuracy(name="binary_accuracy", dtype=None, threshold=threshold),
]
dependencies = {
    metric_name: mean_iou_threshold,
}
imgTester.test(-1, 5, imgTester_metrics, threshold, dependencies)

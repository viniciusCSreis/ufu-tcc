# %%
import os
import tensorflow as tf
import models.unet as unet
from model_util import ImgTester, model_path
from model_util import Saver
from model_util import load_all_imgs

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available", len(physical_devices))
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Num GPUs Available 1

# %%
kernel_size=(3, 3)
padding="same"
strides=1
image_size = (256,256)
epochs = 30
batch_size= 8
validation_split= 0.2
f = [16, 32, 64, 128, 256]
threshold = 0.5
metric_name = "mean_iou_threshold"
metric = tf.keras.metrics.MeanIoU(num_classes=2)
def mean_iou_threshold(y_true, y_pred):
    y_pred = y_pred.numpy()
    y_pred[y_pred > threshold]= 1
    y_pred[y_pred <= threshold] = 0
    metric.reset_states()
    metric.update_state(y_true, y_pred)
    return metric.result().numpy()

base_output_path = '..\\imagens_cra\\result\\unet_epoch_'+str(epochs)+'_size_'+str(image_size)
x_dir = "../imagens_cra/train/cra"
y_dir = "../imagens_cra/validation/cra"

# %%
# Load images
trainImgs = load_all_imgs(x_dir,image_size, 1)
validImgs = load_all_imgs(y_dir,image_size, 0)
# Out:
# ../imagens_cra/train/cra found 659 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ../imagens_cra/validation/cra found 659 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||

# %%
import matplotlib.pyplot as plt
plt.imshow(trainImgs[0])

# %%
plt.imshow(validImgs[0], cmap=plt.cm.binary)

# %%
model = unet.build(image_size, f)
model.compile(run_eagerly=True,optimizer="adam", loss="binary_crossentropy", metrics=mean_iou_threshold)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 16) 2320        conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 16) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 32) 4640        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 32) 9248        conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 64)   36928       conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 128)  147584      conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 256)  590080      conv2d_8[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 256)  0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 384)  0           up_sampling2d[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 256)  884992      concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 256)  590080      conv2d_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 256)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 320)  0           up_sampling2d_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 128)  368768      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 128)  147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 128 0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 160 0           up_sampling2d_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 64) 92224       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 64) 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 80) 0           up_sampling2d_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 32) 23072       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 32) 9248        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 1)  289         conv2d_17[0][0]
# ==================================================================================================
# Total params: 3,331,953
# Trainable params: 3,331,953
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
try:
    os.mkdir(base_output_path)
except OSError as error:
  pass

callbacks = tf.keras.callbacks.ModelCheckpoint(
    model_path(base_output_path),
    verbose=0,
    save_best_only=True,
)
history = model.fit(
    trainImgs, validImgs,
    epochs=epochs,  batch_size=batch_size, callbacks=callbacks,
    validation_split=validation_split,
)
# Out:
# Epoch 1/30
# 66/66 [==============================] - 43s 387ms/step - loss: 0.6288 - mean_iou_threshold: 0.4016 - val_loss: 0.4729 - val_mean_iou_threshold: 0.4020
# Epoch 2/30
# 66/66 [==============================] - 20s 300ms/step - loss: 0.4599 - mean_iou_threshold: 0.4006 - val_loss: 0.4006 - val_mean_iou_threshold: 0.4020
# Epoch 3/30
# 66/66 [==============================] - 19s 291ms/step - loss: 0.4182 - mean_iou_threshold: 0.4016 - val_loss: 0.4238 - val_mean_iou_threshold: 0.4020
# Epoch 4/30
# 66/66 [==============================] - 19s 292ms/step - loss: 0.4033 - mean_iou_threshold: 0.4023 - val_loss: 0.4055 - val_mean_iou_threshold: 0.4020
# Epoch 5/30
# 66/66 [==============================] - 19s 292ms/step - loss: 0.3844 - mean_iou_threshold: 0.4047 - val_loss: 0.3565 - val_mean_iou_threshold: 0.4020
# Epoch 6/30
# 66/66 [==============================] - 19s 292ms/step - loss: 0.3507 - mean_iou_threshold: 0.4518 - val_loss: 0.3178 - val_mean_iou_threshold: 0.5299
# Epoch 7/30
# 66/66 [==============================] - 19s 294ms/step - loss: 0.3517 - mean_iou_threshold: 0.5614 - val_loss: 0.3316 - val_mean_iou_threshold: 0.7006
# Epoch 8/30
# 66/66 [==============================] - 20s 298ms/step - loss: 0.2882 - mean_iou_threshold: 0.6571 - val_loss: 0.2254 - val_mean_iou_threshold: 0.7492
# Epoch 9/30
# 66/66 [==============================] - 19s 293ms/step - loss: 0.2281 - mean_iou_threshold: 0.7317 - val_loss: 0.1461 - val_mean_iou_threshold: 0.8430
# Epoch 10/30
# 66/66 [==============================] - 19s 292ms/step - loss: 0.1353 - mean_iou_threshold: 0.8515 - val_loss: 0.0665 - val_mean_iou_threshold: 0.9257
# Epoch 11/30
# 66/66 [==============================] - 19s 295ms/step - loss: 0.0616 - mean_iou_threshold: 0.9317 - val_loss: 0.0429 - val_mean_iou_threshold: 0.9523
# Epoch 12/30
# 66/66 [==============================] - 20s 298ms/step - loss: 0.0470 - mean_iou_threshold: 0.9454 - val_loss: 0.0661 - val_mean_iou_threshold: 0.9253
# Epoch 13/30
# 66/66 [==============================] - 20s 298ms/step - loss: 0.0438 - mean_iou_threshold: 0.9500 - val_loss: 0.0383 - val_mean_iou_threshold: 0.9569
# Epoch 14/30
# 66/66 [==============================] - 19s 295ms/step - loss: 0.0340 - mean_iou_threshold: 0.9604 - val_loss: 0.0397 - val_mean_iou_threshold: 0.9545
# Epoch 15/30
# 66/66 [==============================] - 20s 298ms/step - loss: 0.0320 - mean_iou_threshold: 0.9626 - val_loss: 0.0330 - val_mean_iou_threshold: 0.9613
# Epoch 16/30
# 66/66 [==============================] - 20s 297ms/step - loss: 0.0231 - mean_iou_threshold: 0.9715 - val_loss: 0.0347 - val_mean_iou_threshold: 0.9608
# Epoch 17/30
# 66/66 [==============================] - 19s 295ms/step - loss: 0.0217 - mean_iou_threshold: 0.9726 - val_loss: 0.0310 - val_mean_iou_threshold: 0.9661
# Epoch 18/30
# 66/66 [==============================] - 19s 296ms/step - loss: 0.0194 - mean_iou_threshold: 0.9761 - val_loss: 0.0310 - val_mean_iou_threshold: 0.9665
# Epoch 19/30
# 66/66 [==============================] - 20s 297ms/step - loss: 0.0189 - mean_iou_threshold: 0.9761 - val_loss: 0.0296 - val_mean_iou_threshold: 0.9679
# Epoch 20/30
# 66/66 [==============================] - 19s 294ms/step - loss: 0.0181 - mean_iou_threshold: 0.9764 - val_loss: 0.0293 - val_mean_iou_threshold: 0.9679
# Epoch 21/30
# 66/66 [==============================] - 19s 295ms/step - loss: 0.0179 - mean_iou_threshold: 0.9772 - val_loss: 0.0285 - val_mean_iou_threshold: 0.9697
# Epoch 22/30
# 66/66 [==============================] - 19s 295ms/step - loss: 0.0170 - mean_iou_threshold: 0.9779 - val_loss: 0.0291 - val_mean_iou_threshold: 0.9663
# Epoch 23/30
# 66/66 [==============================] - 19s 294ms/step - loss: 0.0178 - mean_iou_threshold: 0.9778 - val_loss: 0.0288 - val_mean_iou_threshold: 0.9701
# Epoch 24/30
# 66/66 [==============================] - 19s 295ms/step - loss: 0.0170 - mean_iou_threshold: 0.9788 - val_loss: 0.0328 - val_mean_iou_threshold: 0.9681
# Epoch 25/30
# 66/66 [==============================] - 20s 299ms/step - loss: 0.0163 - mean_iou_threshold: 0.9792 - val_loss: 0.0290 - val_mean_iou_threshold: 0.9703
# Epoch 26/30
# 66/66 [==============================] - 20s 300ms/step - loss: 0.0162 - mean_iou_threshold: 0.9794 - val_loss: 0.0300 - val_mean_iou_threshold: 0.9704
# Epoch 27/30
# 66/66 [==============================] - 19s 295ms/step - loss: 0.0162 - mean_iou_threshold: 0.9789 - val_loss: 0.0318 - val_mean_iou_threshold: 0.9688
# Epoch 28/30
# 66/66 [==============================] - 20s 303ms/step - loss: 0.0155 - mean_iou_threshold: 0.9798 - val_loss: 0.0298 - val_mean_iou_threshold: 0.9698
# Epoch 29/30
# 66/66 [==============================] - 20s 300ms/step - loss: 0.0153 - mean_iou_threshold: 0.9804 - val_loss: 0.0321 - val_mean_iou_threshold: 0.9701
# Epoch 30/30
# 66/66 [==============================] - 20s 296ms/step - loss: 0.0153 - mean_iou_threshold: 0.9803 - val_loss: 0.0288 - val_mean_iou_threshold: 0.9706

# %%
internal_saver = Saver(model, history, base_output_path)
internal_saver.save_metrics(metric_name)
# Out:
# saved to: ..\imagens_cra\result\unet_epoch_30_size_(256, 256)\acc_por_epocas

# %%
internal_saver.save_loss()
# Out:
# saved to: ..\imagens_cra\result\unet_epoch_30_size_(256, 256)\loss_por_epocas

# %%
imgTester_metrics = [metric]
imgTester = ImgTester(base_output_path, x_dir, y_dir, image_size)
dependencies = {
    metric_name: mean_iou_threshold,
}
imgTester.test(-1, 5, imgTester_metrics, threshold, dependencies)
# Out:
# found 659 img to test
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Write metrics to: ..\imagens_cra\result\unet_epoch_30_size_(256, 256)\metrics.csv

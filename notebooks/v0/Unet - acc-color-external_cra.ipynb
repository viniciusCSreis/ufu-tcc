# %%
import os
import tensorflow as tf
from TCC.model_util import ImgTester, model_path
from TCC.model_util import Saver
from TCC.model_util import load_all_imgs

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available", len(physical_devices))
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Num GPUs Available 1

# %%
kernel_size=(3, 3)
padding="same"
strides=1
image_size = (256,256)
epochs = 30
batch_size= 8
validation_split= 0.2
f = [16, 32, 64, 128, 256]
threshold = 0.5
metric = tf.keras.metrics.BinaryAccuracy(
    name="binary_accuracy", dtype=None, threshold=threshold
)
base_output_path = '..\\imagens_cra\\result\\unet_default_epoch_'+str(epochs)+'_size_'+str(image_size)
x_dir = "../imagens_cra/train/cra"
y_dir = "../imagens_cra/validation/cra"

# %%
# Load images
trainImgs = load_all_imgs(x_dir,image_size, 1)
validImgs = load_all_imgs(y_dir,image_size, 0)
# Out:
# ../imagens_cra/train/cra found 659 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ../imagens_cra/validation/cra found 659 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||

# %%
import matplotlib.pyplot as plt
plt.imshow(trainImgs[0])

# %%
plt.imshow(validImgs[0], cmap=plt.cm.binary)

# %%
model = unet.build(image_size, f)
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=[metric])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 16) 2320        conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 16) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 32) 4640        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 32) 9248        conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 64)   36928       conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 128)  147584      conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 256)  590080      conv2d_8[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 256)  0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 384)  0           up_sampling2d[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 256)  884992      concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 256)  590080      conv2d_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 256)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 320)  0           up_sampling2d_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 128)  368768      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 128)  147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 128 0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 160 0           up_sampling2d_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 64) 92224       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 64) 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 80) 0           up_sampling2d_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 32) 23072       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 32) 9248        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 1)  33          conv2d_17[0][0]
# ==================================================================================================
# Total params: 3,331,697
# Trainable params: 3,331,697
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
try:
    os.mkdir(base_output_path)
except OSError as error:
  pass

callbacks = tf.keras.callbacks.ModelCheckpoint(
    model_path(base_output_path),
    monitor='binary_accuracy', verbose=0,
    save_best_only=True,
    mode='auto',
    save_freq='epoch',
)
history = model.fit(
    trainImgs, validImgs,
    epochs=epochs,  batch_size=batch_size, callbacks=callbacks,
    validation_split=validation_split,
)
# Out:
# Epoch 1/30
# 66/66 [==============================] - 32s 342ms/step - loss: 0.6268 - binary_accuracy: 0.8041 - val_loss: 0.4620 - val_binary_accuracy: 0.8018
# Epoch 2/30
# 66/66 [==============================] - 14s 208ms/step - loss: 0.4317 - binary_accuracy: 0.7999 - val_loss: 0.4149 - val_binary_accuracy: 0.8018
# Epoch 3/30
# 66/66 [==============================] - 14s 209ms/step - loss: 0.4003 - binary_accuracy: 0.8062 - val_loss: 0.4054 - val_binary_accuracy: 0.8018
# Epoch 4/30
# 66/66 [==============================] - 14s 209ms/step - loss: 0.4023 - binary_accuracy: 0.8058 - val_loss: 0.3679 - val_binary_accuracy: 0.8018
# Epoch 5/30
# 66/66 [==============================] - 14s 209ms/step - loss: 0.3937 - binary_accuracy: 0.7901 - val_loss: 0.3302 - val_binary_accuracy: 0.8389
# Epoch 6/30
# 66/66 [==============================] - 14s 209ms/step - loss: 0.3328 - binary_accuracy: 0.8500 - val_loss: 0.2520 - val_binary_accuracy: 0.9021
# Epoch 7/30
# 66/66 [==============================] - 14s 210ms/step - loss: 0.2996 - binary_accuracy: 0.8669 - val_loss: 0.2483 - val_binary_accuracy: 0.8984
# Epoch 8/30
# 66/66 [==============================] - 14s 210ms/step - loss: 0.2502 - binary_accuracy: 0.8891 - val_loss: 0.1974 - val_binary_accuracy: 0.9198
# Epoch 9/30
# 66/66 [==============================] - 14s 210ms/step - loss: 0.1541 - binary_accuracy: 0.9376 - val_loss: 0.0749 - val_binary_accuracy: 0.9716
# Epoch 10/30
# 66/66 [==============================] - 14s 211ms/step - loss: 0.0641 - binary_accuracy: 0.9749 - val_loss: 0.1117 - val_binary_accuracy: 0.9607
# Epoch 11/30
# 66/66 [==============================] - 14s 211ms/step - loss: 0.0595 - binary_accuracy: 0.9771 - val_loss: 0.0443 - val_binary_accuracy: 0.9819
# Epoch 12/30
# 66/66 [==============================] - 14s 211ms/step - loss: 0.0332 - binary_accuracy: 0.9858 - val_loss: 0.0610 - val_binary_accuracy: 0.9772
# Epoch 13/30
# 66/66 [==============================] - 14s 211ms/step - loss: 0.0372 - binary_accuracy: 0.9849 - val_loss: 0.0726 - val_binary_accuracy: 0.9774
# Epoch 14/30
# 66/66 [==============================] - 14s 211ms/step - loss: 0.0326 - binary_accuracy: 0.9867 - val_loss: 0.0414 - val_binary_accuracy: 0.9843
# Epoch 15/30
# 66/66 [==============================] - 14s 211ms/step - loss: 0.0226 - binary_accuracy: 0.9897 - val_loss: 0.0371 - val_binary_accuracy: 0.9855
# Epoch 16/30
# 66/66 [==============================] - 14s 211ms/step - loss: 0.0220 - binary_accuracy: 0.9899 - val_loss: 0.0347 - val_binary_accuracy: 0.9865
# Epoch 17/30
# 66/66 [==============================] - 14s 211ms/step - loss: 0.0195 - binary_accuracy: 0.9908 - val_loss: 0.0300 - val_binary_accuracy: 0.9875
# Epoch 18/30
# 66/66 [==============================] - 14s 211ms/step - loss: 0.0189 - binary_accuracy: 0.9910 - val_loss: 0.0334 - val_binary_accuracy: 0.9873
# Epoch 19/30
# 66/66 [==============================] - 14s 212ms/step - loss: 0.0182 - binary_accuracy: 0.9912 - val_loss: 0.0306 - val_binary_accuracy: 0.9876
# Epoch 20/30
# 66/66 [==============================] - 14s 211ms/step - loss: 0.0180 - binary_accuracy: 0.9913 - val_loss: 0.0314 - val_binary_accuracy: 0.9878
# Epoch 21/30
# 66/66 [==============================] - 14s 212ms/step - loss: 0.0179 - binary_accuracy: 0.9913 - val_loss: 0.0302 - val_binary_accuracy: 0.9880
# Epoch 22/30
# 66/66 [==============================] - 14s 212ms/step - loss: 0.0173 - binary_accuracy: 0.9915 - val_loss: 0.0304 - val_binary_accuracy: 0.9884
# Epoch 23/30
# 66/66 [==============================] - 14s 212ms/step - loss: 0.0166 - binary_accuracy: 0.9918 - val_loss: 0.0286 - val_binary_accuracy: 0.9885
# Epoch 24/30
# 66/66 [==============================] - 14s 212ms/step - loss: 0.0160 - binary_accuracy: 0.9920 - val_loss: 0.0309 - val_binary_accuracy: 0.9884
# Epoch 25/30
# 66/66 [==============================] - 14s 212ms/step - loss: 0.0153 - binary_accuracy: 0.9923 - val_loss: 0.0301 - val_binary_accuracy: 0.9885
# Epoch 26/30
# 66/66 [==============================] - 14s 212ms/step - loss: 0.0162 - binary_accuracy: 0.9920 - val_loss: 0.0321 - val_binary_accuracy: 0.9884
# Epoch 27/30
# 66/66 [==============================] - 14s 212ms/step - loss: 0.0158 - binary_accuracy: 0.9921 - val_loss: 0.0293 - val_binary_accuracy: 0.9886
# Epoch 28/30
#  - ETA: 11s - loss: 0.0144 - binary_accuracy: 0.9926
# Epoch 29/30
# 66/66 [==============================] - 14s 212ms/step - loss: 0.0151 - binary_accuracy: 0.9924 - val_loss: 0.0306 - val_binary_accuracy: 0.9886
# Epoch 30/30
# 66/66 [==============================] - 14s 212ms/step - loss: 0.0148 - binary_accuracy: 0.9925 - val_loss: 0.0303 - val_binary_accuracy: 0.9889

# %%
internal_saver = Saver(model, history, base_output_path)
internal_saver.save_metrics("binary_accuracy")
# Out:
# saved to: ..\imagens_cra\result\unet_default_epoch_30_size_(256, 256)\acc_por_epocas

# %%
internal_saver.save_loss()
# Out:
# saved to: ..\imagens_cra\result\unet_default_epoch_30_size_(256, 256)\loss_por_epocas

# %%
imgTester_metrics = [metric, tf.keras.metrics.MeanIoU(num_classes=2)]
imgTester = ImgTester(base_output_path, x_dir, y_dir, image_size)
imgTester.test(-1, 5, imgTester_metrics, threshold)
# Out:
# found 659 img to test
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Write metrics to: ..\imagens_cra\result\unet_default_epoch_30_size_(256, 256)\metrics.csv

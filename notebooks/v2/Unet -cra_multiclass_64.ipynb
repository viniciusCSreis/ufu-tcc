# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from TCC.model_util import load_all_imgs, Saver, ImgTesterV2, test_v2
from TCC.model_util import model_path

from TCC.models.unet_v2 import unet_v2_get_model

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available", len(physical_devices))
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Num GPUs Available 1

# %%
image_size = (64, 64)
epochs = 30
batch_size= 8
num_classes = 3
validation_split= 0.2
f = [64]
threshold = 0.5
metric_name = "mean_iou_threshold"
metric = tf.keras.metrics.MeanIoU(num_classes=2, name=metric_name)
def mean_iou_threshold(y_true, y_pred):
    y_pred = y_pred.numpy()
    y_pred[y_pred > threshold]= 1
    y_pred[y_pred <= threshold] = 0
    metric.reset_states()
    metric.update_state(y_true, y_pred)
    return metric.result().numpy()

os.chdir("../..")
base_output_path = '../imagens_cra/result/v2/unet_multiclass_epoch_'+str(epochs)+'_size_'+str(image_size)
x_dir = "../imagens_cra/train/cra"
y_dir = "../imagens_cra/validation_interna_externa_v2/cra"


print("base_output_path:", base_output_path)
try:
    os.mkdir(base_output_path)
except OSError as error:
    pass
# Out:
# base_output_path: ../imagens_cra/result/v2/unet_multiclass_epoch_30_size_(64, 64)

# %%
# Load images
trainImgs = load_all_imgs(x_dir,image_size, 1)

y_imgs = load_all_imgs(y_dir,image_size, 0)
y_imgs = y_imgs * 255.0


validImgs = np.zeros(y_imgs.shape + (3, ) )

validImgs[y_imgs == 0] = np.array([1, 0, 0])
validImgs[y_imgs == 1] = np.array([0, 1, 0])
validImgs[y_imgs == 2] = np.array([0, 0, 1])
# Out:
# ../imagens_cra/train/cra found 659 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ../imagens_cra/validation_interna_externa_v2/cra found 659 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||

# %%
img_to_test = int(len(trainImgs) * (1 - validation_split))
x_train = trainImgs[0:img_to_test]
y_train = validImgs[0:img_to_test]
x_val = trainImgs[img_to_test:]
y_val = validImgs[img_to_test:]
validation_data = (x_val, y_val)
print("ImgToTest:",img_to_test)
print("Validation_data_size:", len(validation_data[0]))
# Out:
# ImgToTest: 527
# Validation_data_size: 132

# %%
plt.imshow(trainImgs[0])

# %%
plt.imshow(y_imgs[0])

# %%
model = unet_v2_get_model(image_size, 3, filters=f)
model.compile(run_eagerly=True,optimizer="rmsprop", loss="categorical_crossentropy", metrics=mean_iou_threshold)
model.summary()
# Out:
# down_sampling_filters: [64]
# up_sampling_filters: [64, 32]
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 32)   128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 32)   0           activation[0][0]
# __________________________________________________________________________________________________
# separable_conv2d (SeparableConv (None, 32, 32, 64)   2400        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 64)   256         separable_conv2d[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 32, 32, 64)   4736        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 16, 16, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 64)   2112        activation[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 16, 16, 64)   0           max_pooling2d[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 64)   36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 64)   256         conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 64)   256         conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 64)   4160        up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 64)   0           up_sampling2d[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 32)   18464       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 32)   128         conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 32, 32, 32)   9248        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 32)   128         conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 32)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 32)   2080        up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 32)   0           up_sampling2d_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 3)    867         add_2[0][0]
# ==================================================================================================
# Total params: 120,227
# Trainable params: 119,523
# Non-trainable params: 704
# __________________________________________________________________________________________________

# %%
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(model_path(base_output_path), save_best_only=True)
]
# Train the model, doing validation at the end of each epoch.
history = model.fit(x_train, y_train,
          epochs=epochs, callbacks=callbacks,
          validation_data=validation_data, batch_size=batch_size
)
# Out:
# Epoch 1/30
# 66/66 [==============================] - 23s 105ms/step - loss: 0.7526 - mean_iou_threshold: 0.7081 - val_loss: 2.9750 - val_mean_iou_threshold: 0.6147
# Epoch 2/30
# 66/66 [==============================] - 6s 88ms/step - loss: 0.2245 - mean_iou_threshold: 0.8766 - val_loss: 4.3019 - val_mean_iou_threshold: 0.6147
# Epoch 3/30
# 66/66 [==============================] - 6s 89ms/step - loss: 0.1495 - mean_iou_threshold: 0.9151 - val_loss: 4.8077 - val_mean_iou_threshold: 0.6147
# Epoch 4/30
# 66/66 [==============================] - 6s 89ms/step - loss: 0.1168 - mean_iou_threshold: 0.9316 - val_loss: 4.7854 - val_mean_iou_threshold: 0.6147
# Epoch 5/30
# 66/66 [==============================] - 6s 90ms/step - loss: 0.0982 - mean_iou_threshold: 0.9423 - val_loss: 4.3338 - val_mean_iou_threshold: 0.6147
# Epoch 6/30
# 66/66 [==============================] - 6s 88ms/step - loss: 0.0861 - mean_iou_threshold: 0.9492 - val_loss: 4.0272 - val_mean_iou_threshold: 0.6145
# Epoch 7/30
# 66/66 [==============================] - 6s 89ms/step - loss: 0.0783 - mean_iou_threshold: 0.9537 - val_loss: 2.8705 - val_mean_iou_threshold: 0.6139
# Epoch 8/30
# 66/66 [==============================] - 6s 89ms/step - loss: 0.0714 - mean_iou_threshold: 0.9575 - val_loss: 0.8623 - val_mean_iou_threshold: 0.7168
# Epoch 9/30
# 66/66 [==============================] - 6s 89ms/step - loss: 0.0673 - mean_iou_threshold: 0.9597 - val_loss: 0.3056 - val_mean_iou_threshold: 0.8628
# Epoch 10/30
# 66/66 [==============================] - 6s 89ms/step - loss: 0.0617 - mean_iou_threshold: 0.9628 - val_loss: 0.1300 - val_mean_iou_threshold: 0.9306
# Epoch 11/30
# 66/66 [==============================] - 6s 92ms/step - loss: 0.0585 - mean_iou_threshold: 0.9647 - val_loss: 0.2804 - val_mean_iou_threshold: 0.8613
# Epoch 12/30
# 66/66 [==============================] - 6s 92ms/step - loss: 0.0572 - mean_iou_threshold: 0.9653 - val_loss: 0.1169 - val_mean_iou_threshold: 0.9344
# Epoch 13/30
# 66/66 [==============================] - 6s 92ms/step - loss: 0.0538 - mean_iou_threshold: 0.9676 - val_loss: 0.1210 - val_mean_iou_threshold: 0.9322
# Epoch 14/30
# 66/66 [==============================] - 6s 90ms/step - loss: 0.0526 - mean_iou_threshold: 0.9682 - val_loss: 0.1380 - val_mean_iou_threshold: 0.9229
# Epoch 15/30
# 66/66 [==============================] - 6s 88ms/step - loss: 0.0526 - mean_iou_threshold: 0.9683 - val_loss: 0.1954 - val_mean_iou_threshold: 0.9027
# Epoch 16/30
# 66/66 [==============================] - 6s 90ms/step - loss: 0.0479 - mean_iou_threshold: 0.9709 - val_loss: 0.1247 - val_mean_iou_threshold: 0.9378
# Epoch 17/30
# 66/66 [==============================] - 6s 89ms/step - loss: 0.0506 - mean_iou_threshold: 0.9699 - val_loss: 0.1202 - val_mean_iou_threshold: 0.9334
# Epoch 18/30
# 66/66 [==============================] - 6s 89ms/step - loss: 0.0460 - mean_iou_threshold: 0.9722 - val_loss: 0.1042 - val_mean_iou_threshold: 0.9419
# Epoch 19/30
# 66/66 [==============================] - 6s 90ms/step - loss: 0.0455 - mean_iou_threshold: 0.9723 - val_loss: 0.0863 - val_mean_iou_threshold: 0.9511
# Epoch 20/30
# 66/66 [==============================] - 6s 90ms/step - loss: 0.0419 - mean_iou_threshold: 0.9745 - val_loss: 0.0790 - val_mean_iou_threshold: 0.9561
# Epoch 21/30
# 66/66 [==============================] - 6s 89ms/step - loss: 0.0402 - mean_iou_threshold: 0.9755 - val_loss: 0.0895 - val_mean_iou_threshold: 0.9507
# Epoch 22/30
# 66/66 [==============================] - 6s 90ms/step - loss: 0.0391 - mean_iou_threshold: 0.9763 - val_loss: 0.1060 - val_mean_iou_threshold: 0.9451
# Epoch 23/30
# 66/66 [==============================] - 6s 90ms/step - loss: 0.0396 - mean_iou_threshold: 0.9759 - val_loss: 0.3012 - val_mean_iou_threshold: 0.8830
# Epoch 24/30
# 66/66 [==============================] - 6s 90ms/step - loss: 0.0375 - mean_iou_threshold: 0.9772 - val_loss: 0.0821 - val_mean_iou_threshold: 0.9552
# Epoch 25/30
# 66/66 [==============================] - 6s 91ms/step - loss: 0.0365 - mean_iou_threshold: 0.9778 - val_loss: 0.9603 - val_mean_iou_threshold: 0.7125
# Epoch 26/30
# 66/66 [==============================] - 6s 91ms/step - loss: 0.0359 - mean_iou_threshold: 0.9780 - val_loss: 0.1664 - val_mean_iou_threshold: 0.9125
# Epoch 27/30
# 66/66 [==============================] - 6s 92ms/step - loss: 0.0356 - mean_iou_threshold: 0.9784 - val_loss: 0.1092 - val_mean_iou_threshold: 0.9425
# Epoch 28/30
# 66/66 [==============================] - 6s 91ms/step - loss: 0.0347 - mean_iou_threshold: 0.9789 - val_loss: 0.0949 - val_mean_iou_threshold: 0.9501
# Epoch 29/30
# 66/66 [==============================] - 6s 92ms/step - loss: 0.0338 - mean_iou_threshold: 0.9796 - val_loss: 0.6557 - val_mean_iou_threshold: 0.7819
# Epoch 30/30
# 66/66 [==============================] - 6s 92ms/step - loss: 0.0329 - mean_iou_threshold: 0.9801 - val_loss: 0.0971 - val_mean_iou_threshold: 0.9481

# %%
tf.keras.backend.clear_session()
internal_saver = Saver(model, history, base_output_path)
internal_saver.save_metrics(metric_name)
# Out:
# saved to: ../imagens_cra/result/v2/unet_multiclass_epoch_30_size_(64, 64)\acc_por_epocas

# %%
internal_saver.save_loss()
# Out:
# saved to: ../imagens_cra/result/v2/unet_multiclass_epoch_30_size_(64, 64)\loss_por_epocas

# %%
imgTester_metrics = [
    metric,
]
metric_name = "mean_iou_threshold"

dependencies = {
    metric_name: mean_iou_threshold,
}

imgUtil = ImgTesterV2(x_dir, y_dir, base_output_path, image_size, imgTester_metrics, dependencies)

test_v2(base_output_path, imgUtil, len(validImgs), 5)
# Out:
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Write metrics to: ../imagens_cra/result/v2/unet_multiclass_epoch_30_size_(64, 64)\metrics.csv

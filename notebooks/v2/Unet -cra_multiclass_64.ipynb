# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from TCC import model_util
from TCC.models.unet import build
from TCC.models.unet_v2 import unet_v2_get_model
from model_util import load_all_imgs, Saver, ImgTesterV2, test_v2
from model_util import model_path

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available", len(physical_devices))
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Num GPUs Available 1

# %%
kernel_size=(3, 3)
padding="same"
strides=1
image_size = (64, 64)
epochs = 30
batch_size= 4
num_classes = 3
validation_split= 0.2
f = [64]

threshold = 0.5
metric_name = "mean_iou_threshold"
metric = tf.keras.metrics.MeanIoU(num_classes=2, name=metric_name)

base_output_path = '..\\imagens_cra\\result\\unet_multiclass_epoch_'+str(epochs)+'_size_'+str(image_size)
x_dir = "../imagens_cra/train/cra"
y_dir = "../imagens_cra/validation_interna_externa_v2/cra"

# %%
# Load images
trainImgs = load_all_imgs(x_dir,image_size, 1)

y_imgs = load_all_imgs(y_dir,image_size, 0)
y_imgs = y_imgs * 255.0


validImgs = np.zeros(y_imgs.shape + (3, ) )

validImgs[y_imgs == 0] = np.array([1, 0, 0])
validImgs[y_imgs == 1] = np.array([0, 1, 0])
validImgs[y_imgs == 2] = np.array([0, 0, 1])
# Out:
# ../imagens_cra/train/cra found 659 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ../imagens_cra/validation_interna_externa_v2/cra found 659 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||

# %%
plt.imshow(trainImgs[0])

# %%
plt.imshow(y_imgs[0])

# %%
def mean_iou_threshold(y_true, y_pred):
    y_pred = y_pred.numpy()
    y_pred[y_pred > threshold]= 1
    y_pred[y_pred <= threshold] = 0
    metric.reset_states()
    metric.update_state(y_true, y_pred)
    return metric.result().numpy()

model = unet_v2_get_model(image_size, 3, filters=f)
model.compile(run_eagerly=True,optimizer="rmsprop", loss="categorical_crossentropy", metrics=mean_iou_threshold)
model.summary()
# Out:
# down_sampling_filters: [64]
# up_sampling_filters: [64, 32]
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 32)   128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 32)   0           activation[0][0]
# __________________________________________________________________________________________________
# separable_conv2d (SeparableConv (None, 32, 32, 64)   2400        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 64)   256         separable_conv2d[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 32, 32, 64)   4736        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 16, 16, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 64)   2112        activation[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 16, 16, 64)   0           max_pooling2d[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 64)   36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 64)   256         conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 64)   256         conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 64)   4160        up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 64)   0           up_sampling2d[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 32)   18464       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 32)   128         conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 32, 32, 32)   9248        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 32)   128         conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 32)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 32)   2080        up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 32)   0           up_sampling2d_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 3)    867         add_2[0][0]
# ==================================================================================================
# Total params: 120,227
# Trainable params: 119,523
# Non-trainable params: 704
# __________________________________________________________________________________________________

# %%
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(model_path(base_output_path), save_best_only=True)
]

# Train the model, doing validation at the end of each epoch.
history = model.fit(trainImgs, validImgs,
          epochs=epochs, callbacks=callbacks,
          validation_split=validation_split, batch_size=batch_size
)
# Out:
# Epoch 1/30
# 132/132 [==============================] - 15s 94ms/step - loss: 0.5849 - mean_iou_threshold: 0.7485 - val_loss: 4.5037 - val_mean_iou_threshold: 0.6153
# Epoch 2/30
# 132/132 [==============================] - 12s 91ms/step - loss: 0.1675 - mean_iou_threshold: 0.9065 - val_loss: 6.1219 - val_mean_iou_threshold: 0.6153
# Epoch 3/30
# 132/132 [==============================] - 12s 91ms/step - loss: 0.1141 - mean_iou_threshold: 0.9343 - val_loss: 3.1639 - val_mean_iou_threshold: 0.6153
# Epoch 4/30
# 132/132 [==============================] - 12s 91ms/step - loss: 0.0922 - mean_iou_threshold: 0.9463 - val_loss: 0.6419 - val_mean_iou_threshold: 0.7041
# Epoch 5/30
# 132/132 [==============================] - 13s 97ms/step - loss: 0.0804 - mean_iou_threshold: 0.9522 - val_loss: 0.2099 - val_mean_iou_threshold: 0.8953
# Epoch 6/30
# 132/132 [==============================] - 12s 91ms/step - loss: 0.0668 - mean_iou_threshold: 0.9599 - val_loss: 0.1160 - val_mean_iou_threshold: 0.9335
# Epoch 7/30
# 132/132 [==============================] - 12s 90ms/step - loss: 0.0647 - mean_iou_threshold: 0.9617 - val_loss: 0.1509 - val_mean_iou_threshold: 0.9223
# Epoch 8/30
# 132/132 [==============================] - 12s 90ms/step - loss: 0.0586 - mean_iou_threshold: 0.9652 - val_loss: 0.0922 - val_mean_iou_threshold: 0.9490
# Epoch 9/30
# 132/132 [==============================] - 12s 91ms/step - loss: 0.0530 - mean_iou_threshold: 0.9680 - val_loss: 0.1068 - val_mean_iou_threshold: 0.9391
# Epoch 10/30
# 132/132 [==============================] - 12s 90ms/step - loss: 0.0511 - mean_iou_threshold: 0.9693 - val_loss: 0.1236 - val_mean_iou_threshold: 0.9309
# Epoch 11/30
# 132/132 [==============================] - 12s 91ms/step - loss: 0.0514 - mean_iou_threshold: 0.9695 - val_loss: 0.0989 - val_mean_iou_threshold: 0.9439
# Epoch 12/30
# 132/132 [==============================] - 12s 91ms/step - loss: 0.0507 - mean_iou_threshold: 0.9697 - val_loss: 0.4541 - val_mean_iou_threshold: 0.8194
# Epoch 13/30
# 132/132 [==============================] - 12s 90ms/step - loss: 0.0452 - mean_iou_threshold: 0.9726 - val_loss: 0.7683 - val_mean_iou_threshold: 0.7254
# Epoch 14/30
# 132/132 [==============================] - 12s 91ms/step - loss: 0.0422 - mean_iou_threshold: 0.9746 - val_loss: 0.1266 - val_mean_iou_threshold: 0.9332
# Epoch 15/30
# 132/132 [==============================] - 12s 91ms/step - loss: 0.0437 - mean_iou_threshold: 0.9734 - val_loss: 0.0924 - val_mean_iou_threshold: 0.9484
# Epoch 16/30
# 132/132 [==============================] - 12s 92ms/step - loss: 0.0395 - mean_iou_threshold: 0.9758 - val_loss: 0.2106 - val_mean_iou_threshold: 0.9019
# Epoch 17/30
# 132/132 [==============================] - 12s 90ms/step - loss: 0.0369 - mean_iou_threshold: 0.9776 - val_loss: 0.3465 - val_mean_iou_threshold: 0.8539
# Epoch 18/30
# 132/132 [==============================] - 12s 90ms/step - loss: 0.0358 - mean_iou_threshold: 0.9782 - val_loss: 0.3292 - val_mean_iou_threshold: 0.8417
# Epoch 19/30
# 132/132 [==============================] - 12s 90ms/step - loss: 0.0355 - mean_iou_threshold: 0.9785 - val_loss: 0.0890 - val_mean_iou_threshold: 0.9509
# Epoch 20/30
# 132/132 [==============================] - 12s 91ms/step - loss: 0.0339 - mean_iou_threshold: 0.9794 - val_loss: 0.0817 - val_mean_iou_threshold: 0.9543
# Epoch 21/30
# 132/132 [==============================] - 12s 91ms/step - loss: 0.0340 - mean_iou_threshold: 0.9793 - val_loss: 0.3422 - val_mean_iou_threshold: 0.8384
# Epoch 22/30
# 132/132 [==============================] - 12s 91ms/step - loss: 0.0324 - mean_iou_threshold: 0.9803 - val_loss: 0.0975 - val_mean_iou_threshold: 0.9493
# Epoch 23/30
# 132/132 [==============================] - 12s 90ms/step - loss: 0.0314 - mean_iou_threshold: 0.9811 - val_loss: 0.1231 - val_mean_iou_threshold: 0.9403
# Epoch 24/30
# 132/132 [==============================] - 12s 90ms/step - loss: 0.0308 - mean_iou_threshold: 0.9813 - val_loss: 0.1714 - val_mean_iou_threshold: 0.9214
# Epoch 25/30
# 132/132 [==============================] - 12s 91ms/step - loss: 0.0298 - mean_iou_threshold: 0.9820 - val_loss: 0.2511 - val_mean_iou_threshold: 0.8873
# Epoch 26/30
# 132/132 [==============================] - 12s 91ms/step - loss: 0.0289 - mean_iou_threshold: 0.9827 - val_loss: 0.4508 - val_mean_iou_threshold: 0.8236
# Epoch 27/30
# 132/132 [==============================] - 12s 91ms/step - loss: 0.0287 - mean_iou_threshold: 0.9827 - val_loss: 0.1335 - val_mean_iou_threshold: 0.9392
# Epoch 28/30
# 132/132 [==============================] - 12s 91ms/step - loss: 0.0268 - mean_iou_threshold: 0.9837 - val_loss: 0.1559 - val_mean_iou_threshold: 0.9286
# Epoch 29/30
# 132/132 [==============================] - 12s 90ms/step - loss: 0.0264 - mean_iou_threshold: 0.9840 - val_loss: 0.1151 - val_mean_iou_threshold: 0.9467
# Epoch 30/30
# 132/132 [==============================] - 13s 102ms/step - loss: 0.0259 - mean_iou_threshold: 0.9843 - val_loss: 0.0923 - val_mean_iou_threshold: 0.9515

# %%
tf.keras.backend.clear_session()
internal_saver = Saver(model, history, base_output_path)
internal_saver.save_metrics(metric_name)
# Out:
# saved to: ..\imagens_cra\result\unet_multiclass_epoch_30_size_(64, 64)\acc_por_epocas

# %%
internal_saver.save_loss()
# Out:
# saved to: ..\imagens_cra\result\unet_multiclass_epoch_30_size_(64, 64)\loss_por_epocas

# %%
imgTester_metrics = [
    metric,
]
metric_name = "mean_iou_threshold"

dependencies = {
    metric_name: mean_iou_threshold,
}

imgUtil = ImgTesterV2(x_dir, y_dir, base_output_path, image_size, imgTester_metrics, dependencies)

test_v2(base_output_path, imgUtil, len(validImgs), 5)
# Out:
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Write metrics to: ..\imagens_cra\result\unet_multiclass_epoch_30_size_(64, 64)\metrics.csv

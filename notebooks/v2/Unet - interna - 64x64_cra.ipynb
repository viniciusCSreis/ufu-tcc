# %%
import os
import tensorflow as tf

from TCC.model_util import ImgTester, model_path
from TCC.model_util import Saver
from TCC.model_util import load_all_imgs
from TCC.models.unet_v2 import unet_v2_get_model

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available", len(physical_devices))
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Num GPUs Available 1

# %%
image_size = (64,64)
epochs = 30
batch_size= 8
validation_split= 0.2
f = [64]
threshold = 0.5
metric_name = "mean_iou_threshold"
metric = tf.keras.metrics.MeanIoU(num_classes=2)
def mean_iou_threshold(y_true, y_pred):
    y_pred = y_pred.numpy()
    y_pred[y_pred > threshold]= 1
    y_pred[y_pred <= threshold] = 0
    metric.reset_states()
    metric.update_state(y_true, y_pred)
    return metric.result().numpy()

os.chdir("../..")
base_output_path = '../imagens_cra/result/v2/unet_interna_epoch_'+str(epochs)+'_size_'+str(image_size)
x_dir = "../imagens_cra/train/cra"
y_dir = "../imagens_cra/validation_interna/cra"

print("base_output_path:", base_output_path)
try:
    os.mkdir(base_output_path)
except OSError as error:
    pass
# Out:
# base_output_path: ../imagens_cra/result/v2/unet_interna_epoch_30_size_(64, 64)

# %%
# Load images
trainImgs = load_all_imgs(x_dir,image_size, 1)
validImgs = load_all_imgs(y_dir,image_size, 0)
# Out:
# ../imagens_cra/train/cra found 659 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ../imagens_cra/validation_interna/cra found 659 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||

# %%
img_to_test = int(len(trainImgs) * 0.8)
x_train = trainImgs[0:img_to_test]
y_train = validImgs[0:img_to_test]
x_val = trainImgs[img_to_test:]
y_val = validImgs[img_to_test:]
validation_data = (x_val, y_val)
print("ImgToTest:",img_to_test)
print("Validation_data_size:", len(validation_data[0]))
# Out:
# ImgToTest: 527
# Validation_data_size: 132

# %%
import matplotlib.pyplot as plt
plt.imshow(trainImgs[0])

# %%
plt.imshow(validImgs[0], cmap=plt.cm.binary)

# %%
model =  unet_v2_get_model(image_size, 1, 'sigmoid', filters=f)
model.compile(run_eagerly=True,optimizer="adam", loss="binary_crossentropy", metrics=mean_iou_threshold)
model.summary()
# Out:
# down_sampling_filters: [64]
# up_sampling_filters: [64, 32]
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 32)   128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 32)   0           activation[0][0]
# __________________________________________________________________________________________________
# separable_conv2d (SeparableConv (None, 32, 32, 64)   2400        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 64)   256         separable_conv2d[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 32, 32, 64)   4736        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 16, 16, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 64)   2112        activation[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 16, 16, 64)   0           max_pooling2d[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 64)   36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 64)   256         conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 64)   256         conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 64)   4160        up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 64)   0           up_sampling2d[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 32)   18464       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 32)   128         conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 32, 32, 32)   9248        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 32)   128         conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 32)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 32)   2080        up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 32)   0           up_sampling2d_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 1)    289         add_2[0][0]
# ==================================================================================================
# Total params: 119,649
# Trainable params: 118,945
# Non-trainable params: 704
# __________________________________________________________________________________________________

# %%
callbacks = tf.keras.callbacks.ModelCheckpoint(
    model_path(base_output_path),
    verbose=0,
    save_best_only=True,
)
history = model.fit(
    x_train, y_train,
    epochs=epochs,  batch_size=batch_size, callbacks=callbacks,
    validation_data=validation_data,
)
# Out:
# Epoch 1/30
# 66/66 [==============================] - 7s 71ms/step - loss: 0.4165 - mean_iou_threshold: 0.5887 - val_loss: 1.4033 - val_mean_iou_threshold: 0.4356
# Epoch 2/30
# 66/66 [==============================] - 4s 57ms/step - loss: 0.1033 - mean_iou_threshold: 0.8338 - val_loss: 1.9993 - val_mean_iou_threshold: 0.4356
# Epoch 3/30
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0624 - mean_iou_threshold: 0.8967 - val_loss: 1.9995 - val_mean_iou_threshold: 0.4356
# Epoch 4/30
# 66/66 [==============================] - 4s 62ms/step - loss: 0.0447 - mean_iou_threshold: 0.9252 - val_loss: 1.9981 - val_mean_iou_threshold: 0.4356
# Epoch 5/30
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0348 - mean_iou_threshold: 0.9395 - val_loss: 1.9766 - val_mean_iou_threshold: 0.4356
# Epoch 6/30
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0315 - mean_iou_threshold: 0.9453 - val_loss: 1.8239 - val_mean_iou_threshold: 0.4356
# Epoch 7/30
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0274 - mean_iou_threshold: 0.9527 - val_loss: 1.1716 - val_mean_iou_threshold: 0.4356
# Epoch 8/30
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0246 - mean_iou_threshold: 0.9570 - val_loss: 0.4650 - val_mean_iou_threshold: 0.5869
# Epoch 9/30
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0229 - mean_iou_threshold: 0.9598 - val_loss: 0.2180 - val_mean_iou_threshold: 0.7325
# Epoch 10/30
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0211 - mean_iou_threshold: 0.9622 - val_loss: 0.2167 - val_mean_iou_threshold: 0.7505
# Epoch 11/30
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0206 - mean_iou_threshold: 0.9636 - val_loss: 0.0743 - val_mean_iou_threshold: 0.8781
# Epoch 12/30
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0188 - mean_iou_threshold: 0.9664 - val_loss: 0.0786 - val_mean_iou_threshold: 0.8864
# Epoch 13/30
# 66/66 [==============================] - 4s 62ms/step - loss: 0.0181 - mean_iou_threshold: 0.9680 - val_loss: 0.0403 - val_mean_iou_threshold: 0.9293
# Epoch 14/30
# 66/66 [==============================] - 4s 59ms/step - loss: 0.0174 - mean_iou_threshold: 0.9694 - val_loss: 0.0397 - val_mean_iou_threshold: 0.9301
# Epoch 15/30
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0167 - mean_iou_threshold: 0.9708 - val_loss: 0.0466 - val_mean_iou_threshold: 0.9200
# Epoch 16/30
# 66/66 [==============================] - 4s 59ms/step - loss: 0.0155 - mean_iou_threshold: 0.9725 - val_loss: 0.0448 - val_mean_iou_threshold: 0.9222
# Epoch 17/30
# 66/66 [==============================] - 4s 59ms/step - loss: 0.0154 - mean_iou_threshold: 0.9733 - val_loss: 0.0444 - val_mean_iou_threshold: 0.9239
# Epoch 18/30
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0151 - mean_iou_threshold: 0.9738 - val_loss: 0.0373 - val_mean_iou_threshold: 0.9379
# Epoch 19/30
# 66/66 [==============================] - 4s 61ms/step - loss: 0.0137 - mean_iou_threshold: 0.9760 - val_loss: 0.0487 - val_mean_iou_threshold: 0.9223
# Epoch 20/30
# 66/66 [==============================] - 4s 61ms/step - loss: 0.0139 - mean_iou_threshold: 0.9752 - val_loss: 0.0362 - val_mean_iou_threshold: 0.9375
# Epoch 21/30
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0132 - mean_iou_threshold: 0.9766 - val_loss: 0.0637 - val_mean_iou_threshold: 0.9027
# Epoch 22/30
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0124 - mean_iou_threshold: 0.9783 - val_loss: 0.1480 - val_mean_iou_threshold: 0.8415
# Epoch 23/30
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0122 - mean_iou_threshold: 0.9783 - val_loss: 0.0555 - val_mean_iou_threshold: 0.9156
# Epoch 24/30
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0121 - mean_iou_threshold: 0.9793 - val_loss: 0.0381 - val_mean_iou_threshold: 0.9386
# Epoch 25/30
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0114 - mean_iou_threshold: 0.9803 - val_loss: 0.0921 - val_mean_iou_threshold: 0.8900
# Epoch 26/30
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0108 - mean_iou_threshold: 0.9810 - val_loss: 0.0715 - val_mean_iou_threshold: 0.9034
# Epoch 27/30
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0107 - mean_iou_threshold: 0.9810 - val_loss: 0.0404 - val_mean_iou_threshold: 0.9364
# Epoch 28/30
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0102 - mean_iou_threshold: 0.9821 - val_loss: 0.0386 - val_mean_iou_threshold: 0.9390
# Epoch 29/30
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0098 - mean_iou_threshold: 0.9827 - val_loss: 0.0400 - val_mean_iou_threshold: 0.9411
# Epoch 30/30
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0102 - mean_iou_threshold: 0.9819 - val_loss: 0.0455 - val_mean_iou_threshold: 0.9322

# %%
internal_saver = Saver(model, history, base_output_path)
internal_saver.save_metrics(metric_name)
# Out:
# saved to: ../imagens_cra/result/v2/unet_interna_epoch_30_size_(64, 64)\acc_por_epocas

# %%
internal_saver.save_loss()
# Out:
# saved to: ../imagens_cra/result/v2/unet_interna_epoch_30_size_(64, 64)\loss_por_epocas

# %%
internal_saver.save_history()
# Out:
# saved to: ../imagens_cra/result/v2/unet_interna_epoch_30_size_(64, 64)\history.json
# saved to: ../imagens_cra/result/v2/unet_interna_epoch_30_size_(64, 64)\history.csv

# %%
imgTester_metrics = [metric]
imgTester = ImgTester(base_output_path, x_dir, y_dir, image_size)
dependencies = {
    metric_name: mean_iou_threshold,
}
imgTester.test(-1, 5, imgTester_metrics, threshold, dependencies)
# Out:
# found 659 img to test
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Write metrics to: ../imagens_cra/result/v2/unet_interna_epoch_30_size_(64, 64)\metrics.csv

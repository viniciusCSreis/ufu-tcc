# %%
import os
import tensorflow as tf
import models.unet as unet
from model_util import ImgTester, model_path
from model_util import Saver
from model_util import load_all_imgs

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available", len(physical_devices))
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Num GPUs Available 1

# %%
kernel_size=(3, 3)
padding="same"
strides=1
image_size = (256,256)
epochs = 30
batch_size= 8
validation_split= 0.2
f = [16, 32, 64, 128, 256]
threshold = 0.5
metric = [
    tf.keras.metrics.BinaryAccuracy(name="binary_accuracy", dtype=None, threshold=threshold),
    tf.keras.metrics.MeanIoU(num_classes=2)
]
base_output_path = '..\\imagens_cra\\result\\unet_acc_iou_epoch_'+str(epochs)+'_size_'+str(image_size)
x_dir = "../imagens_cra/train/cra"
y_dir = "../imagens_cra/validation/cra"

# %%
# Load images
trainImgs = load_all_imgs(x_dir,image_size, 1)
validImgs = load_all_imgs(y_dir,image_size, 0)
# Out:
# ../imagens_cra/train/cra found 659 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ../imagens_cra/validation/cra found 659 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||

# %%
import matplotlib.pyplot as plt
plt.imshow(trainImgs[0])

# %%
plt.imshow(validImgs[0], cmap=plt.cm.binary)

# %%
model = unet.build(image_size, f)
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=[metric])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 16) 2320        conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 16) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 32) 4640        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 32) 9248        conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 64)   36928       conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 128)  147584      conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 256)  590080      conv2d_8[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 256)  0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 384)  0           up_sampling2d[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 256)  884992      concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 256)  590080      conv2d_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 256)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 320)  0           up_sampling2d_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 128)  368768      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 128)  147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 128 0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 160 0           up_sampling2d_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 64) 92224       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 64) 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 80) 0           up_sampling2d_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 32) 23072       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 32) 9248        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 1)  33          conv2d_17[0][0]
# ==================================================================================================
# Total params: 3,331,697
# Trainable params: 3,331,697
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
try:
    os.mkdir(base_output_path)
except OSError as error:
  pass

callbacks = tf.keras.callbacks.ModelCheckpoint(
    model_path(base_output_path),
    monitor='binary_accuracy', verbose=0,
    save_best_only=True,
    mode='auto',
    save_freq='epoch',
)
history = model.fit(
    trainImgs, validImgs,
    epochs=epochs,  batch_size=batch_size, callbacks=callbacks,
    validation_split=validation_split,
)
# Out:
# Epoch 1/30
#  - ETA: 9s - loss: 0.6214 - binary_accuracy: 0.8077 - mean_io_u_1: 0.4053
# Epoch 2/30
# 66/66 [==============================] - 14s 216ms/step - loss: 0.4690 - binary_accuracy: 0.8055 - mean_io_u_1: 0.4041 - val_loss: 0.4163 - val_binary_accuracy: 0.8018 - val_mean_io_u_1: 0.4023
# Epoch 3/30
# 66/66 [==============================] - 14s 217ms/step - loss: 0.4257 - binary_accuracy: 0.7982 - mean_io_u_1: 0.4005 - val_loss: 0.3910 - val_binary_accuracy: 0.8018 - val_mean_io_u_1: 0.4023
# Epoch 4/30
# 66/66 [==============================] - 14s 217ms/step - loss: 0.4001 - binary_accuracy: 0.8035 - mean_io_u_1: 0.4020 - val_loss: 0.3268 - val_binary_accuracy: 0.8658 - val_mean_io_u_1: 0.4023
# Epoch 5/30
# 66/66 [==============================] - 14s 217ms/step - loss: 0.3234 - binary_accuracy: 0.8531 - mean_io_u_1: 0.4055 - val_loss: 0.2683 - val_binary_accuracy: 0.8828 - val_mean_io_u_1: 0.4023
# Epoch 6/30
# 66/66 [==============================] - 14s 217ms/step - loss: 0.2616 - binary_accuracy: 0.8838 - mean_io_u_1: 0.4030 - val_loss: 0.2944 - val_binary_accuracy: 0.8829 - val_mean_io_u_1: 0.4023
# Epoch 7/30
# 66/66 [==============================] - 14s 217ms/step - loss: 0.2486 - binary_accuracy: 0.8915 - mean_io_u_1: 0.4024 - val_loss: 0.4233 - val_binary_accuracy: 0.8823 - val_mean_io_u_1: 0.4023
# Epoch 8/30
# 66/66 [==============================] - 14s 218ms/step - loss: 0.3296 - binary_accuracy: 0.8547 - mean_io_u_1: 0.4029 - val_loss: 0.1366 - val_binary_accuracy: 0.9471 - val_mean_io_u_1: 0.4023
# Epoch 9/30
# 66/66 [==============================] - 14s 217ms/step - loss: 0.1157 - binary_accuracy: 0.9557 - mean_io_u_1: 0.4016 - val_loss: 0.0668 - val_binary_accuracy: 0.9730 - val_mean_io_u_1: 0.4023
# Epoch 10/30
# 66/66 [==============================] - 14s 218ms/step - loss: 0.0580 - binary_accuracy: 0.9770 - mean_io_u_1: 0.4035 - val_loss: 0.0602 - val_binary_accuracy: 0.9767 - val_mean_io_u_1: 0.4024
# Epoch 11/30
# 66/66 [==============================] - 14s 219ms/step - loss: 0.0401 - binary_accuracy: 0.9834 - mean_io_u_1: 0.4037 - val_loss: 0.0392 - val_binary_accuracy: 0.9841 - val_mean_io_u_1: 0.4031
# Epoch 12/30
# 66/66 [==============================] - 14s 218ms/step - loss: 0.0314 - binary_accuracy: 0.9864 - mean_io_u_1: 0.4026 - val_loss: 0.0343 - val_binary_accuracy: 0.9859 - val_mean_io_u_1: 0.4043
# Epoch 13/30
# 66/66 [==============================] - 14s 219ms/step - loss: 0.0259 - binary_accuracy: 0.9883 - mean_io_u_1: 0.4058 - val_loss: 0.0316 - val_binary_accuracy: 0.9866 - val_mean_io_u_1: 0.4033
# Epoch 14/30
#  - ETA: 2s - loss: 0.0241 - binary_accuracy: 0.9889 - mean_io_u_1: 0.4038
# Epoch 15/30
# 66/66 [==============================] - 14s 219ms/step - loss: 0.0733 - binary_accuracy: 0.9712 - mean_io_u_1: 0.4058 - val_loss: 0.0427 - val_binary_accuracy: 0.9818 - val_mean_io_u_1: 0.4024
# Epoch 16/30
# 66/66 [==============================] - 14s 219ms/step - loss: 0.0372 - binary_accuracy: 0.9844 - mean_io_u_1: 0.4053 - val_loss: 0.0319 - val_binary_accuracy: 0.9864 - val_mean_io_u_1: 0.4044
# Epoch 17/30
# 66/66 [==============================] - 14s 218ms/step - loss: 0.0283 - binary_accuracy: 0.9875 - mean_io_u_1: 0.4048 - val_loss: 0.0279 - val_binary_accuracy: 0.9880 - val_mean_io_u_1: 0.4044
# Epoch 18/30
# 66/66 [==============================] - 14s 218ms/step - loss: 0.0212 - binary_accuracy: 0.9900 - mean_io_u_1: 0.4081 - val_loss: 0.0296 - val_binary_accuracy: 0.9878 - val_mean_io_u_1: 0.4037
# Epoch 19/30
# 66/66 [==============================] - 14s 219ms/step - loss: 0.0202 - binary_accuracy: 0.9904 - mean_io_u_1: 0.4032 - val_loss: 0.0295 - val_binary_accuracy: 0.9877 - val_mean_io_u_1: 0.4041
# Epoch 20/30
# 66/66 [==============================] - 14s 218ms/step - loss: 0.0198 - binary_accuracy: 0.9905 - mean_io_u_1: 0.4044 - val_loss: 0.0275 - val_binary_accuracy: 0.9885 - val_mean_io_u_1: 0.4034
# Epoch 21/30
# 66/66 [==============================] - 14s 219ms/step - loss: 0.0188 - binary_accuracy: 0.9909 - mean_io_u_1: 0.4073 - val_loss: 0.0272 - val_binary_accuracy: 0.9890 - val_mean_io_u_1: 0.4040
# Epoch 22/30
# 66/66 [==============================] - 14s 219ms/step - loss: 0.0179 - binary_accuracy: 0.9912 - mean_io_u_1: 0.4063 - val_loss: 0.0264 - val_binary_accuracy: 0.9890 - val_mean_io_u_1: 0.4062
# Epoch 23/30
# 66/66 [==============================] - 14s 220ms/step - loss: 0.0177 - binary_accuracy: 0.9913 - mean_io_u_1: 0.4094 - val_loss: 0.0263 - val_binary_accuracy: 0.9893 - val_mean_io_u_1: 0.4065
# Epoch 24/30
# 66/66 [==============================] - 14s 220ms/step - loss: 0.0171 - binary_accuracy: 0.9916 - mean_io_u_1: 0.4108 - val_loss: 0.0277 - val_binary_accuracy: 0.9891 - val_mean_io_u_1: 0.4140
# Epoch 25/30
# 66/66 [==============================] - 14s 220ms/step - loss: 0.0176 - binary_accuracy: 0.9913 - mean_io_u_1: 0.4084 - val_loss: 0.1139 - val_binary_accuracy: 0.9482 - val_mean_io_u_1: 0.4023
# Epoch 26/30
# 66/66 [==============================] - 14s 220ms/step - loss: 0.0410 - binary_accuracy: 0.9829 - mean_io_u_1: 0.4140 - val_loss: 0.0292 - val_binary_accuracy: 0.9876 - val_mean_io_u_1: 0.4119
# Epoch 27/30
# 66/66 [==============================] - 15s 220ms/step - loss: 0.0205 - binary_accuracy: 0.9904 - mean_io_u_1: 0.4203 - val_loss: 0.0258 - val_binary_accuracy: 0.9892 - val_mean_io_u_1: 0.4189
# Epoch 28/30
# 66/66 [==============================] - 14s 220ms/step - loss: 0.0183 - binary_accuracy: 0.9912 - mean_io_u_1: 0.4207 - val_loss: 0.0237 - val_binary_accuracy: 0.9896 - val_mean_io_u_1: 0.4126
# Epoch 29/30
#  - ETA: 1s - loss: 0.0181 - binary_accuracy: 0.9913 - mean_io_u_1: 0.4168
# Epoch 30/30
# 66/66 [==============================] - 14s 220ms/step - loss: 0.0170 - binary_accuracy: 0.9917 - mean_io_u_1: 0.4207 - val_loss: 0.0246 - val_binary_accuracy: 0.9899 - val_mean_io_u_1: 0.4079

# %%
internal_saver = Saver(model, history, base_output_path)
internal_saver.save_metrics("binary_accuracy")
# Out:
# saved to: ..\imagens_cra\result\unet_acc_iou_epoch_30_size_(256, 256)\acc_por_epocas

# %%
internal_saver.save_loss()
# Out:
# saved to: ..\imagens_cra\result\unet_acc_iou_epoch_30_size_(256, 256)\loss_por_epocas

# %%
imgTester_metrics = metric
imgTester = ImgTester(base_output_path, x_dir, y_dir, image_size)
imgTester.test(-1, 5, imgTester_metrics, threshold)
# Out:
# found 659 img to test
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Write metrics to: ..\imagens_cra\result\unet_acc_iou_epoch_30_size_(256, 256)\metrics.csv

# %%
import os
import tensorflow as tf
import models.unet as unet
from model_util import ImgTester, model_path
from model_util import Saver
from model_util import load_all_imgs

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available", len(physical_devices))
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Num GPUs Available 1

# %%
kernel_size=(3, 3)
padding="same"
strides=1
image_size = (256,256)
epochs = 30
batch_size= 8
validation_split= 0.2
f = [16, 32, 64, 128, 256]
threshold = 0.5
metric_name = "mean_iou_threshold"
metric = tf.keras.metrics.MeanIoU(num_classes=2)
def mean_iou_threshold(y_true, y_pred):
    y_pred = y_pred.numpy()
    y_pred[y_pred > threshold]= 1
    y_pred[y_pred <= threshold] = 0
    metric.reset_states()
    metric.update_state(y_true, y_pred)
    return metric.result().numpy()

base_output_path = '..\\imagens_cra\\result\\unet_interna_epoch_'+str(epochs)+'_size_'+str(image_size)
x_dir = "../imagens_cra/train/cra"
y_dir = "../imagens_cra/validation_interna/cra"

# %%
# Load images
trainImgs = load_all_imgs(x_dir,image_size, 1)
validImgs = load_all_imgs(y_dir,image_size, 0)
# Out:
# ../imagens_cra/train/cra found 659 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ../imagens_cra/validation_interna/cra found 659 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||

# %%
import matplotlib.pyplot as plt
plt.imshow(trainImgs[0])

# %%
plt.imshow(validImgs[0], cmap=plt.cm.binary)

# %%
model = unet.build(image_size, f)
model.compile(run_eagerly=True,optimizer="adam", loss="binary_crossentropy", metrics=mean_iou_threshold)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 16) 2320        conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 16) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 32) 4640        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 32) 9248        conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 64)   36928       conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 128)  147584      conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 256)  590080      conv2d_8[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 256)  0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 384)  0           up_sampling2d[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 256)  884992      concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 256)  590080      conv2d_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 256)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 320)  0           up_sampling2d_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 128)  368768      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 128)  147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 128 0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 160 0           up_sampling2d_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 64) 92224       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 64) 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 80) 0           up_sampling2d_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 32) 23072       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 32) 9248        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 1)  289         conv2d_17[0][0]
# ==================================================================================================
# Total params: 3,331,953
# Trainable params: 3,331,953
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
try:
    os.mkdir(base_output_path)
except OSError as error:
  pass

callbacks = tf.keras.callbacks.ModelCheckpoint(
    model_path(base_output_path),
    verbose=0,
    save_best_only=True,
)
history = model.fit(
    trainImgs, validImgs,
    epochs=epochs,  batch_size=batch_size, callbacks=callbacks,
    validation_split=validation_split,
)
# Out:
# Epoch 1/30
# 66/66 [==============================] - 32s 378ms/step - loss: 0.4567 - mean_iou_threshold: 0.4074 - val_loss: 0.2868 - val_mean_iou_threshold: 0.4356
# Epoch 2/30
# 66/66 [==============================] - 19s 289ms/step - loss: 0.2634 - mean_iou_threshold: 0.4403 - val_loss: 0.2198 - val_mean_iou_threshold: 0.6625
# Epoch 3/30
# 66/66 [==============================] - 19s 292ms/step - loss: 0.2218 - mean_iou_threshold: 0.6780 - val_loss: 0.2151 - val_mean_iou_threshold: 0.6851
# Epoch 4/30
# 66/66 [==============================] - 19s 290ms/step - loss: 0.2074 - mean_iou_threshold: 0.6859 - val_loss: 0.2208 - val_mean_iou_threshold: 0.6879
# Epoch 5/30
# 66/66 [==============================] - 19s 291ms/step - loss: 0.1990 - mean_iou_threshold: 0.7042 - val_loss: 0.1965 - val_mean_iou_threshold: 0.7074
# Epoch 6/30
# 66/66 [==============================] - 19s 291ms/step - loss: 0.1881 - mean_iou_threshold: 0.7226 - val_loss: 0.1909 - val_mean_iou_threshold: 0.6949
# Epoch 7/30
# 66/66 [==============================] - 19s 291ms/step - loss: 0.1853 - mean_iou_threshold: 0.7286 - val_loss: 0.2700 - val_mean_iou_threshold: 0.6148
# Epoch 8/30
# 66/66 [==============================] - 19s 294ms/step - loss: 0.2464 - mean_iou_threshold: 0.5953 - val_loss: 0.2085 - val_mean_iou_threshold: 0.6860
# Epoch 9/30
# 66/66 [==============================] - 19s 293ms/step - loss: 0.1916 - mean_iou_threshold: 0.7112 - val_loss: 0.1341 - val_mean_iou_threshold: 0.8242
# Epoch 10/30
# 66/66 [==============================] - 19s 292ms/step - loss: 0.0564 - mean_iou_threshold: 0.9162 - val_loss: 0.0432 - val_mean_iou_threshold: 0.9290
# Epoch 11/30
# 66/66 [==============================] - 19s 293ms/step - loss: 0.0204 - mean_iou_threshold: 0.9655 - val_loss: 0.0238 - val_mean_iou_threshold: 0.9598
# Epoch 12/30
# 66/66 [==============================] - 19s 293ms/step - loss: 0.0155 - mean_iou_threshold: 0.9730 - val_loss: 0.0208 - val_mean_iou_threshold: 0.9646
# Epoch 13/30
# 66/66 [==============================] - 19s 293ms/step - loss: 0.0118 - mean_iou_threshold: 0.9792 - val_loss: 0.0206 - val_mean_iou_threshold: 0.9654
# Epoch 14/30
# 66/66 [==============================] - 19s 292ms/step - loss: 0.0111 - mean_iou_threshold: 0.9809 - val_loss: 0.0168 - val_mean_iou_threshold: 0.9729
# Epoch 15/30
# 66/66 [==============================] - 19s 294ms/step - loss: 0.0101 - mean_iou_threshold: 0.9824 - val_loss: 0.0173 - val_mean_iou_threshold: 0.9727
# Epoch 16/30
# 66/66 [==============================] - 19s 292ms/step - loss: 0.0092 - mean_iou_threshold: 0.9839 - val_loss: 0.0148 - val_mean_iou_threshold: 0.9762
# Epoch 17/30
# 66/66 [==============================] - 19s 292ms/step - loss: 0.0089 - mean_iou_threshold: 0.9848 - val_loss: 0.0181 - val_mean_iou_threshold: 0.9729
# Epoch 18/30
# 66/66 [==============================] - 19s 292ms/step - loss: 0.0086 - mean_iou_threshold: 0.9849 - val_loss: 0.0188 - val_mean_iou_threshold: 0.9706
# Epoch 19/30
# 66/66 [==============================] - 19s 292ms/step - loss: 0.0119 - mean_iou_threshold: 0.9811 - val_loss: 0.0234 - val_mean_iou_threshold: 0.9633
# Epoch 20/30
# 66/66 [==============================] - 19s 292ms/step - loss: 0.0091 - mean_iou_threshold: 0.9845 - val_loss: 0.0143 - val_mean_iou_threshold: 0.9779
# Epoch 21/30
# 66/66 [==============================] - 19s 293ms/step - loss: 0.0082 - mean_iou_threshold: 0.9861 - val_loss: 0.0138 - val_mean_iou_threshold: 0.9784
# Epoch 22/30
# 66/66 [==============================] - 19s 293ms/step - loss: 0.0076 - mean_iou_threshold: 0.9869 - val_loss: 0.0132 - val_mean_iou_threshold: 0.9789
# Epoch 23/30
# 66/66 [==============================] - 19s 293ms/step - loss: 0.0080 - mean_iou_threshold: 0.9863 - val_loss: 0.0140 - val_mean_iou_threshold: 0.9786
# Epoch 24/30
# 66/66 [==============================] - 19s 294ms/step - loss: 0.0075 - mean_iou_threshold: 0.9871 - val_loss: 0.0156 - val_mean_iou_threshold: 0.9775
# Epoch 25/30
# 66/66 [==============================] - 19s 293ms/step - loss: 0.0074 - mean_iou_threshold: 0.9871 - val_loss: 0.0151 - val_mean_iou_threshold: 0.9778
# Epoch 26/30
# 66/66 [==============================] - 19s 293ms/step - loss: 0.0072 - mean_iou_threshold: 0.9876 - val_loss: 0.0139 - val_mean_iou_threshold: 0.9795
# Epoch 27/30
# 66/66 [==============================] - 19s 293ms/step - loss: 0.0070 - mean_iou_threshold: 0.9879 - val_loss: 0.0138 - val_mean_iou_threshold: 0.9798
# Epoch 28/30
# 66/66 [==============================] - 19s 293ms/step - loss: 0.0072 - mean_iou_threshold: 0.9875 - val_loss: 0.0135 - val_mean_iou_threshold: 0.9801
# Epoch 29/30
# 66/66 [==============================] - 19s 293ms/step - loss: 0.0070 - mean_iou_threshold: 0.9883 - val_loss: 0.0131 - val_mean_iou_threshold: 0.9806
# Epoch 30/30
# 66/66 [==============================] - 19s 293ms/step - loss: 0.0076 - mean_iou_threshold: 0.9870 - val_loss: 0.0187 - val_mean_iou_threshold: 0.9713

# %%
internal_saver = Saver(model, history, base_output_path)
internal_saver.save_metrics(metric_name)
# Out:
# saved to: ..\imagens_cra\result\unet_interna_epoch_30_size_(256, 256)\acc_por_epocas

# %%
internal_saver.save_loss()
# Out:
# saved to: ..\imagens_cra\result\unet_interna_epoch_30_size_(256, 256)\loss_por_epocas

# %%
imgTester_metrics = [metric]
imgTester = ImgTester(base_output_path, x_dir, y_dir, image_size)
dependencies = {
    metric_name: mean_iou_threshold,
}
imgTester.test(-1, 5, imgTester_metrics, threshold, dependencies)
# Out:
# found 659 img to test
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Write metrics to: ..\imagens_cra\result\unet_interna_epoch_30_size_(256, 256)\metrics.csv

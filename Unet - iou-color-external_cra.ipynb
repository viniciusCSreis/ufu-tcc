# %%
import os
import tensorflow as tf
import models.unet as unet
from model_util import ImgTester, model_path
from model_util import Saver
from model_util import load_all_imgs

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available", len(physical_devices))
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Num GPUs Available 1

# %%
kernel_size=(3, 3)
padding="same"
strides=1
image_size = (256,256)
epochs = 30
batch_size= 8
validation_split= 0.2
f = [16, 32, 64, 128, 256]
threshold = 0.5
metric_name = "mean_io_u"
metric = tf.keras.metrics.MeanIoU(num_classes=2, name=metric_name)
base_output_path = '..\\imagens_cra\\result\\unet_iou_epoch_'+str(epochs)+'_size_'+str(image_size)
x_dir = "../imagens_cra/train/cra"
y_dir = "../imagens_cra/validation/cra"

# %%
# Load images
trainImgs = load_all_imgs(x_dir,image_size, 1)
validImgs = load_all_imgs(y_dir,image_size, 0)
# Out:
# ../imagens_cra/train/cra found 659 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ../imagens_cra/validation/cra found 659 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||

# %%
import matplotlib.pyplot as plt
plt.imshow(trainImgs[0])

# %%
plt.imshow(validImgs[0], cmap=plt.cm.binary)

# %%
model = unet.build(image_size, f)
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=[metric])
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 256, 256, 16) 448         input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 256, 256, 16) 2320        conv2d_38[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 128, 128, 16) 0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 128, 128, 32) 4640        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 128, 128, 32) 9248        conv2d_40[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 64, 64, 32)   0           conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 64, 64, 64)   18496       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 64, 64, 64)   36928       conv2d_42[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 32, 32, 64)   0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 32, 32, 128)  73856       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 32, 32, 128)  147584      conv2d_44[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 16, 16, 128)  0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 16, 16, 256)  295168      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 16, 16, 256)  590080      conv2d_46[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 32, 32, 256)  0           conv2d_47[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 32, 32, 384)  0           up_sampling2d_8[0][0]
#                                                                  conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 32, 32, 256)  884992      concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 32, 32, 256)  590080      conv2d_48[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_9 (UpSampling2D)  (None, 64, 64, 256)  0           conv2d_49[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 64, 64, 320)  0           up_sampling2d_9[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 64, 64, 128)  368768      concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 64, 64, 128)  147584      conv2d_50[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_10 (UpSampling2D) (None, 128, 128, 128 0           conv2d_51[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 128, 128, 160 0           up_sampling2d_10[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 128, 128, 64) 92224       concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_52[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, 256, 256, 64) 0           conv2d_53[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 256, 256, 80) 0           up_sampling2d_11[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 256, 256, 32) 23072       concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 256, 256, 32) 9248        conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 256, 256, 1)  33          conv2d_55[0][0]
# ==================================================================================================
# Total params: 3,331,697
# Trainable params: 3,331,697
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
try:
    os.mkdir(base_output_path)
except OSError as error:
  pass

callbacks = tf.keras.callbacks.ModelCheckpoint(
    model_path(base_output_path),
    monitor=metric_name, verbose=0,
    save_best_only=True,
    mode='auto',
    save_freq='epoch',
)
history = model.fit(
    trainImgs, validImgs,
    epochs=epochs,  batch_size=batch_size, callbacks=callbacks,
    validation_split=validation_split,
)
# Out:
# Epoch 1/30
# 66/66 [==============================] - 16s 221ms/step - loss: 0.5442 - mean_io_u: 0.4050 - val_loss: 0.4246 - val_mean_io_u: 0.4023
# Epoch 2/30
# 66/66 [==============================] - 14s 214ms/step - loss: 0.4300 - mean_io_u: 0.4036 - val_loss: 0.4209 - val_mean_io_u: 0.4023
# Epoch 3/30
# 66/66 [==============================] - 14s 214ms/step - loss: 0.4175 - mean_io_u: 0.4020 - val_loss: 0.3916 - val_mean_io_u: 0.4023
# Epoch 4/30
# 66/66 [==============================] - 14s 214ms/step - loss: 0.3889 - mean_io_u: 0.4033 - val_loss: 0.3090 - val_mean_io_u: 0.4023
# Epoch 5/30
# 66/66 [==============================] - 14s 215ms/step - loss: 0.3410 - mean_io_u: 0.4017 - val_loss: 0.2844 - val_mean_io_u: 0.4023
# Epoch 6/30
# 66/66 [==============================] - 14s 215ms/step - loss: 0.2970 - mean_io_u: 0.4017 - val_loss: 0.2634 - val_mean_io_u: 0.4023
# Epoch 7/30
# 66/66 [==============================] - 14s 215ms/step - loss: 0.2388 - mean_io_u: 0.4013 - val_loss: 0.2554 - val_mean_io_u: 0.4023
# Epoch 8/30
# 66/66 [==============================] - 14s 215ms/step - loss: 0.1720 - mean_io_u: 0.4034 - val_loss: 0.2319 - val_mean_io_u: 0.4039
# Epoch 9/30
# 66/66 [==============================] - 14s 215ms/step - loss: 0.1282 - mean_io_u: 0.4011 - val_loss: 0.0692 - val_mean_io_u: 0.4023
# Epoch 10/30
# 66/66 [==============================] - 14s 216ms/step - loss: 0.0573 - mean_io_u: 0.4021 - val_loss: 0.0540 - val_mean_io_u: 0.4023
# Epoch 11/30
# 66/66 [==============================] - 14s 216ms/step - loss: 0.0521 - mean_io_u: 0.3990 - val_loss: 0.0441 - val_mean_io_u: 0.4023
# Epoch 12/30
# 66/66 [==============================] - 14s 216ms/step - loss: 0.0336 - mean_io_u: 0.4022 - val_loss: 0.0505 - val_mean_io_u: 0.4042
# Epoch 13/30
# 66/66 [==============================] - 14s 216ms/step - loss: 0.0350 - mean_io_u: 0.4024 - val_loss: 0.0375 - val_mean_io_u: 0.4023
# Epoch 14/30
# 66/66 [==============================] - 14s 216ms/step - loss: 0.0255 - mean_io_u: 0.4020 - val_loss: 0.0454 - val_mean_io_u: 0.4023
# Epoch 15/30
# 66/66 [==============================] - 14s 215ms/step - loss: 0.0272 - mean_io_u: 0.4014 - val_loss: 0.0374 - val_mean_io_u: 0.4025
# Epoch 16/30
# 66/66 [==============================] - 14s 216ms/step - loss: 0.0247 - mean_io_u: 0.4031 - val_loss: 0.0355 - val_mean_io_u: 0.4025
# Epoch 17/30
# 66/66 [==============================] - 14s 216ms/step - loss: 0.0220 - mean_io_u: 0.4058 - val_loss: 0.0382 - val_mean_io_u: 0.4107
# Epoch 18/30
# 66/66 [==============================] - 14s 218ms/step - loss: 0.0348 - mean_io_u: 0.4131 - val_loss: 0.0392 - val_mean_io_u: 0.4034
# Epoch 19/30
# 66/66 [==============================] - 15s 223ms/step - loss: 0.0259 - mean_io_u: 0.4064 - val_loss: 0.0386 - val_mean_io_u: 0.4023
# Epoch 20/30
# 66/66 [==============================] - 14s 218ms/step - loss: 0.0340 - mean_io_u: 0.4021 - val_loss: 0.0316 - val_mean_io_u: 0.4034
# Epoch 21/30
# 66/66 [==============================] - 14s 218ms/step - loss: 0.0201 - mean_io_u: 0.4075 - val_loss: 0.0314 - val_mean_io_u: 0.4027
# Epoch 22/30
# 66/66 [==============================] - 14s 217ms/step - loss: 0.0200 - mean_io_u: 0.4044 - val_loss: 0.0295 - val_mean_io_u: 0.4030
# Epoch 23/30
# 66/66 [==============================] - 14s 218ms/step - loss: 0.0184 - mean_io_u: 0.4054 - val_loss: 0.0310 - val_mean_io_u: 0.4093
# Epoch 24/30
# 66/66 [==============================] - 14s 217ms/step - loss: 0.0178 - mean_io_u: 0.4093 - val_loss: 0.0332 - val_mean_io_u: 0.4109
# Epoch 25/30
# 66/66 [==============================] - 14s 218ms/step - loss: 0.0183 - mean_io_u: 0.4078 - val_loss: 0.0316 - val_mean_io_u: 0.4047
# Epoch 26/30
# 66/66 [==============================] - 14s 217ms/step - loss: 0.0172 - mean_io_u: 0.4042 - val_loss: 0.0308 - val_mean_io_u: 0.4095
# Epoch 27/30
# 66/66 [==============================] - 14s 218ms/step - loss: 0.0165 - mean_io_u: 0.4086 - val_loss: 0.0346 - val_mean_io_u: 0.4061
# Epoch 28/30
# 66/66 [==============================] - 14s 218ms/step - loss: 0.0163 - mean_io_u: 0.4114 - val_loss: 0.0344 - val_mean_io_u: 0.4023
# Epoch 29/30
# 66/66 [==============================] - 14s 217ms/step - loss: 0.0161 - mean_io_u: 0.4051 - val_loss: 0.0350 - val_mean_io_u: 0.4071
# Epoch 30/30
# 66/66 [==============================] - 14s 217ms/step - loss: 0.0154 - mean_io_u: 0.4097 - val_loss: 0.0314 - val_mean_io_u: 0.4038

# %%
internal_saver = Saver(model, history, base_output_path)
internal_saver.save_metrics(metric_name)
# Out:
# saved to: ..\imagens_cra\result\unet_iou_epoch_30_size_(256, 256)\acc_por_epocas

# %%
internal_saver.save_loss()
# Out:
# saved to: ..\imagens_cra\result\unet_iou_epoch_30_size_(256, 256)\loss_por_epocas

# %%
imgTester_metrics = [metric, tf.keras.metrics.BinaryAccuracy(
    name="binary_accuracy", dtype=None, threshold=threshold
)]
imgTester = ImgTester(base_output_path, x_dir, y_dir, image_size)
imgTester.test(5, 5, imgTester_metrics, threshold)
# Out:
# found 659 img to test
#
# [0]:||||
# Write metrics to: ..\imagens_cra\result\unet_iou_epoch_30_size_(256, 256)\metrics.csv

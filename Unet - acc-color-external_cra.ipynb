# %%
import os
import tensorflow as tf
import models.unet as unet
from model_util import ImgTester, model_path
from model_util import Saver
from model_util import load_all_imgs

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available", len(physical_devices))
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Num GPUs Available 1

# %%
kernel_size=(3, 3)
padding="same"
strides=1
image_size = (256,256)
epochs = 30
batch_size=8
f = [16, 32, 64, 128, 256]
threshold = 0.5
metric = tf.keras.metrics.BinaryAccuracy(
    name="binary_accuracy", dtype=None, threshold=threshold
)
base_output_path = '..\\imagens_cra\\result\\unet_default_epoch_'+str(epochs)+'_size_'+str(image_size)
x_dir = "../imagens_cra/train/cra"
y_dir = "../imagens_cra/validation/cra"

# %%
# Load images
trainImgs = load_all_imgs(x_dir,image_size, 1)
validImgs = load_all_imgs(y_dir,image_size, 0)
# Out:
# ../imagens_cra/train/cra found 659 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ../imagens_cra/validation/cra found 659 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||

# %%
import matplotlib.pyplot as plt
plt.imshow(trainImgs[0])

# %%
plt.imshow(validImgs[0], cmap=plt.cm.binary)

# %%
model = unet.build(image_size, f)
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=[metric])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 16) 2320        conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 16) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 32) 4640        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 32) 9248        conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 64)   36928       conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 128)  147584      conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 256)  590080      conv2d_8[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 256)  0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 384)  0           up_sampling2d[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 256)  884992      concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 256)  590080      conv2d_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 256)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 320)  0           up_sampling2d_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 128)  368768      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 128)  147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 128 0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 160 0           up_sampling2d_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 64) 92224       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 64) 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 80) 0           up_sampling2d_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 32) 23072       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 32) 9248        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 1)  33          conv2d_17[0][0]
# ==================================================================================================
# Total params: 3,331,697
# Trainable params: 3,331,697
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
try:
    os.mkdir(base_output_path)
except OSError as error:
  pass

callbacks = tf.keras.callbacks.ModelCheckpoint(
    model_path(base_output_path),
    monitor='binary_accuracy', verbose=0,
    save_best_only=True,
    mode='auto',
    save_freq='epoch',
)
history = model.fit(
    trainImgs, validImgs,
    epochs=epochs,  batch_size=batch_size, callbacks=callbacks,
)
# Out:
# Epoch 1/30
# 83/83 [==============================] - 31s 251ms/step - loss: 0.5444 - binary_accuracy: 0.7988
# Epoch 2/30
# 83/83 [==============================] - 16s 196ms/step - loss: 0.5205 - binary_accuracy: 0.8031
# Epoch 3/30
# 83/83 [==============================] - 16s 197ms/step - loss: 0.4408 - binary_accuracy: 0.8003
# Epoch 4/30
# 83/83 [==============================] - 16s 197ms/step - loss: 0.4331 - binary_accuracy: 0.7993
# Epoch 5/30
# 83/83 [==============================] - 16s 196ms/step - loss: 0.3755 - binary_accuracy: 0.8300
# Epoch 6/30
# 83/83 [==============================] - 16s 197ms/step - loss: 0.3649 - binary_accuracy: 0.8339
# Epoch 7/30
# 83/83 [==============================] - 16s 197ms/step - loss: 0.3139 - binary_accuracy: 0.8699
# Epoch 8/30
# 83/83 [==============================] - 16s 197ms/step - loss: 0.2763 - binary_accuracy: 0.8848
# Epoch 9/30
# 83/83 [==============================] - 17s 200ms/step - loss: 0.2421 - binary_accuracy: 0.9007
# Epoch 10/30
# 83/83 [==============================] - 17s 200ms/step - loss: 0.1625 - binary_accuracy: 0.9338
# Epoch 11/30
# 83/83 [==============================] - 16s 198ms/step - loss: 0.0831 - binary_accuracy: 0.9669
# Epoch 12/30
# 83/83 [==============================] - 16s 197ms/step - loss: 0.0618 - binary_accuracy: 0.9762
# Epoch 13/30
# 83/83 [==============================] - 16s 197ms/step - loss: 0.0497 - binary_accuracy: 0.9798
# Epoch 14/30
# 83/83 [==============================] - 16s 198ms/step - loss: 0.0429 - binary_accuracy: 0.9823
# Epoch 15/30
# 83/83 [==============================] - 16s 198ms/step - loss: 0.0374 - binary_accuracy: 0.9845
# Epoch 16/30
# 83/83 [==============================] - 16s 198ms/step - loss: 0.0363 - binary_accuracy: 0.9848
# Epoch 17/30
# 83/83 [==============================] - 16s 197ms/step - loss: 0.0296 - binary_accuracy: 0.9870
# Epoch 18/30
# 83/83 [==============================] - 16s 198ms/step - loss: 0.0268 - binary_accuracy: 0.9880
# Epoch 19/30
# 83/83 [==============================] - 17s 200ms/step - loss: 0.0247 - binary_accuracy: 0.9889
# Epoch 20/30
# 83/83 [==============================] - 17s 200ms/step - loss: 0.0240 - binary_accuracy: 0.9891
# Epoch 21/30
# 83/83 [==============================] - 17s 199ms/step - loss: 0.0242 - binary_accuracy: 0.9890
# Epoch 22/30
# 83/83 [==============================] - 17s 199ms/step - loss: 0.0215 - binary_accuracy: 0.9900
# Epoch 23/30
# 83/83 [==============================] - 16s 199ms/step - loss: 0.0215 - binary_accuracy: 0.9900
# Epoch 24/30
# 83/83 [==============================] - 17s 200ms/step - loss: 0.0695 - binary_accuracy: 0.9733
# Epoch 25/30
# 83/83 [==============================] - 17s 200ms/step - loss: 0.0352 - binary_accuracy: 0.9853
# Epoch 26/30
# 83/83 [==============================] - 16s 198ms/step - loss: 0.0305 - binary_accuracy: 0.9871
# Epoch 27/30
# 83/83 [==============================] - 17s 200ms/step - loss: 0.0259 - binary_accuracy: 0.9884
# Epoch 28/30
# 83/83 [==============================] - 17s 199ms/step - loss: 0.0223 - binary_accuracy: 0.9899
# Epoch 29/30
# 83/83 [==============================] - 17s 199ms/step - loss: 0.0208 - binary_accuracy: 0.9903
# Epoch 30/30
# 83/83 [==============================] - 17s 200ms/step - loss: 0.0207 - binary_accuracy: 0.9904

# %%
internal_saver = Saver(model, history, base_output_path)
internal_saver.save_metrics("binary_accuracy")
# Out:
# saved to: ..\imagens_cra\result\unet_default_epoch_30_size_(256, 256)\acc_por_epocas

# %%
internal_saver.save_loss()
# Out:
# saved to: ..\imagens_cra\result\unet_default_epoch_30_size_(256, 256)\loss_por_epocas

# %%
test_metric =  tf.keras.metrics.Accuracy()
imgTester = ImgTester(base_output_path, x_dir, y_dir, image_size)
imgTester.test(-1, 5, metric, threshold)
# Out:
# found 659 img to test
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [200]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [300]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [400]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [500]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [600]:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Write metrics to: ..\imagens_cra\result\unet_default_epoch_30_size_(256, 256)\metrics.csv
